# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('data_ap_s_a_p.csv')

# %%
kategor = 0
data_kategori = dsa.loc[dsa['Pelayanan'] == kategor]

d = data_kategori.head(100)

kategori = 1
data_i = dsa.loc[dsa['Pelayanan'] == kategori]

data_gabungan = pd.concat([d, data_i])

# %%
count_label = data_gabungan['Pelayanan'].value_counts()

# Membuat diagram batang
plt.bar(count_label.index, count_label.values)
plt.xticks([0, 1])
plt.xlabel('Label')
plt.ylabel('Jumlah Data')
plt.title('Distribusi Label pada Dataset')
plt.show()

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Pelayanan']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 226ms/step - loss: 0.6611 - accuracy: 0.7935 - val_loss: 0.5852 - val_accuracy: 0.8981
# Epoch 2/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4590 - accuracy: 0.8794 - val_loss: 0.3018 - val_accuracy: 0.8981
# Epoch 3/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3879 - accuracy: 0.8794 - val_loss: 0.3102 - val_accuracy: 0.8981
# Epoch 4/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.3505 - accuracy: 0.8794 - val_loss: 0.3103 - val_accuracy: 0.8981
# Epoch 5/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3448 - accuracy: 0.8794 - val_loss: 0.3005 - val_accuracy: 0.8981
# Epoch 6/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.3174 - accuracy: 0.8794 - val_loss: 0.2794 - val_accuracy: 0.8981
# Epoch 7/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3083 - accuracy: 0.8794 - val_loss: 0.2702 - val_accuracy: 0.8981
# Epoch 8/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2941 - accuracy: 0.8794 - val_loss: 0.2621 - val_accuracy: 0.8981
# Epoch 9/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2752 - accuracy: 0.8794 - val_loss: 0.2557 - val_accuracy: 0.8981
# Epoch 10/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2436 - accuracy: 0.8794 - val_loss: 0.2540 - val_accuracy: 0.8981
# Epoch 11/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2152 - accuracy: 0.8840 - val_loss: 0.2564 - val_accuracy: 0.9074
# Epoch 12/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1578 - accuracy: 0.9443 - val_loss: 0.2642 - val_accuracy: 0.9074
# Epoch 13/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0754 - accuracy: 0.9814 - val_loss: 0.3393 - val_accuracy: 0.8981
# Epoch 14/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0415 - accuracy: 0.9907 - val_loss: 0.3995 - val_accuracy: 0.8981
# Epoch 15/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0397 - accuracy: 0.9954 - val_loss: 0.4399 - val_accuracy: 0.8981
# Epoch 16/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0420 - accuracy: 0.9930 - val_loss: 0.4867 - val_accuracy: 0.8704
# Epoch 17/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0285 - accuracy: 0.9977 - val_loss: 0.4993 - val_accuracy: 0.8889
# Epoch 18/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0174 - accuracy: 0.9977 - val_loss: 0.5302 - val_accuracy: 0.8981
# Epoch 19/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.5515 - val_accuracy: 0.8704
# Epoch 20/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0158 - accuracy: 0.9977 - val_loss: 0.5390 - val_accuracy: 0.8704
# Epoch 21/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0179 - accuracy: 0.9977 - val_loss: 0.5167 - val_accuracy: 0.8889
# Epoch 22/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0109 - accuracy: 0.9977 - val_loss: 0.5322 - val_accuracy: 0.9074
# Epoch 23/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0268 - accuracy: 0.9930 - val_loss: 0.7157 - val_accuracy: 0.8519
# Epoch 24/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0445 - accuracy: 0.9861 - val_loss: 0.5758 - val_accuracy: 0.8796
# Epoch 25/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0210 - accuracy: 0.9954 - val_loss: 0.6439 - val_accuracy: 0.8889
# Epoch 26/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0241 - accuracy: 0.9930 - val_loss: 0.5145 - val_accuracy: 0.9074
# Epoch 27/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4897 - val_accuracy: 0.8981
# Epoch 28/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0139 - accuracy: 0.9977 - val_loss: 0.4916 - val_accuracy: 0.8981
# Epoch 29/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.4687 - val_accuracy: 0.8981
# Epoch 30/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0126 - accuracy: 0.9977 - val_loss: 0.4752 - val_accuracy: 0.8981
# Epoch 31/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0117 - accuracy: 0.9977 - val_loss: 0.4742 - val_accuracy: 0.8981
# Epoch 32/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.4708 - val_accuracy: 0.9074
# Epoch 33/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0126 - accuracy: 0.9977 - val_loss: 0.4711 - val_accuracy: 0.9074
# Epoch 34/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0103 - accuracy: 0.9977 - val_loss: 0.4982 - val_accuracy: 0.8981
# Epoch 35/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.9074
# Epoch 36/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.4379 - val_accuracy: 0.9074
# Epoch 37/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4697 - val_accuracy: 0.8981
# Epoch 38/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4759 - val_accuracy: 0.9074
# Epoch 39/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4799 - val_accuracy: 0.9074
# Epoch 40/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0039 - accuracy: 0.9977 - val_loss: 0.4811 - val_accuracy: 0.8981
# Epoch 41/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4835 - val_accuracy: 0.9074
# Epoch 42/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4869 - val_accuracy: 0.9074
# Epoch 43/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.9074
# Epoch 44/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4950 - val_accuracy: 0.9074
# Epoch 45/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5008 - val_accuracy: 0.9074
# Epoch 46/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5053 - val_accuracy: 0.9074
# Epoch 47/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5102 - val_accuracy: 0.8981
# Epoch 48/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5149 - val_accuracy: 0.8981
# Epoch 49/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5195 - val_accuracy: 0.8981
# Epoch 50/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5240 - val_accuracy: 0.8981
# Epoch 51/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5288 - val_accuracy: 0.8981
# Epoch 52/100
# 7/7 [==============================] - 0s 31ms/step - loss: 8.0679e-04 - accuracy: 1.0000 - val_loss: 0.5328 - val_accuracy: 0.8981
# Epoch 53/100
# 7/7 [==============================] - 0s 34ms/step - loss: 8.8319e-04 - accuracy: 1.0000 - val_loss: 0.5365 - val_accuracy: 0.8981
# Epoch 54/100
# 7/7 [==============================] - 0s 37ms/step - loss: 7.0460e-04 - accuracy: 1.0000 - val_loss: 0.5398 - val_accuracy: 0.8981
# Epoch 55/100
# 7/7 [==============================] - 0s 37ms/step - loss: 7.4299e-04 - accuracy: 1.0000 - val_loss: 0.5428 - val_accuracy: 0.8981
# Epoch 56/100
# 7/7 [==============================] - 0s 34ms/step - loss: 7.5961e-04 - accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.8981
# Epoch 57/100
# 7/7 [==============================] - 0s 34ms/step - loss: 9.4242e-04 - accuracy: 1.0000 - val_loss: 0.5490 - val_accuracy: 0.8981
# Epoch 58/100
# 7/7 [==============================] - 0s 32ms/step - loss: 8.5611e-04 - accuracy: 1.0000 - val_loss: 0.5526 - val_accuracy: 0.8981
# Epoch 59/100
# 7/7 [==============================] - 0s 39ms/step - loss: 6.8771e-04 - accuracy: 1.0000 - val_loss: 0.5564 - val_accuracy: 0.8981
# Epoch 60/100
# 7/7 [==============================] - 0s 34ms/step - loss: 6.2357e-04 - accuracy: 1.0000 - val_loss: 0.5599 - val_accuracy: 0.8981
# Epoch 61/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.6830e-04 - accuracy: 1.0000 - val_loss: 0.5633 - val_accuracy: 0.8981
# Epoch 62/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.9070e-04 - accuracy: 1.0000 - val_loss: 0.5665 - val_accuracy: 0.8981
# Epoch 63/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.0863e-04 - accuracy: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.8981
# Epoch 64/100
# 7/7 [==============================] - 0s 31ms/step - loss: 5.5374e-04 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.8981
# Epoch 65/100
# 7/7 [==============================] - 0s 31ms/step - loss: 5.6054e-04 - accuracy: 1.0000 - val_loss: 0.5741 - val_accuracy: 0.8981
# Epoch 66/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.9789e-04 - accuracy: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.8981
# Epoch 67/100
# 7/7 [==============================] - 0s 31ms/step - loss: 4.7766e-04 - accuracy: 1.0000 - val_loss: 0.5800 - val_accuracy: 0.9074
# Epoch 68/100
# 7/7 [==============================] - 0s 33ms/step - loss: 4.8183e-04 - accuracy: 1.0000 - val_loss: 0.5829 - val_accuracy: 0.9074
# Epoch 69/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.7702e-04 - accuracy: 1.0000 - val_loss: 0.5862 - val_accuracy: 0.9074
# Epoch 70/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.9636e-04 - accuracy: 1.0000 - val_loss: 0.5892 - val_accuracy: 0.9074
# Epoch 71/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.9489e-04 - accuracy: 1.0000 - val_loss: 0.5923 - val_accuracy: 0.9074
# Epoch 72/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.9538e-04 - accuracy: 1.0000 - val_loss: 0.5952 - val_accuracy: 0.9074
# Epoch 73/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.8658e-04 - accuracy: 1.0000 - val_loss: 0.5980 - val_accuracy: 0.9074
# Epoch 74/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.9246e-04 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.9074
# Epoch 75/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.0615e-04 - accuracy: 1.0000 - val_loss: 0.6032 - val_accuracy: 0.9074
# Epoch 76/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.8200e-04 - accuracy: 1.0000 - val_loss: 0.6060 - val_accuracy: 0.9074
# Epoch 77/100
# 7/7 [==============================] - 0s 31ms/step - loss: 3.4222e-04 - accuracy: 1.0000 - val_loss: 0.6088 - val_accuracy: 0.9074
# Epoch 78/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.7585e-04 - accuracy: 1.0000 - val_loss: 0.6113 - val_accuracy: 0.9074
# Epoch 79/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0021 - accuracy: 0.9977 - val_loss: 0.6127 - val_accuracy: 0.9074
# Epoch 80/100
# 7/7 [==============================] - 0s 31ms/step - loss: 3.3086e-04 - accuracy: 1.0000 - val_loss: 0.6144 - val_accuracy: 0.9074
# Epoch 81/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.4515e-04 - accuracy: 1.0000 - val_loss: 0.6165 - val_accuracy: 0.9074
# Epoch 82/100
# 7/7 [==============================] - 0s 37ms/step - loss: 4.2594e-04 - accuracy: 1.0000 - val_loss: 0.6191 - val_accuracy: 0.9074
# Epoch 83/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.3588e-04 - accuracy: 1.0000 - val_loss: 0.6212 - val_accuracy: 0.9074
# Epoch 84/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.7223e-04 - accuracy: 1.0000 - val_loss: 0.6232 - val_accuracy: 0.9074
# Epoch 85/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.6826e-04 - accuracy: 1.0000 - val_loss: 0.6253 - val_accuracy: 0.9074
# Epoch 86/100
# 7/7 [==============================] - 0s 37ms/step - loss: 3.4753e-04 - accuracy: 1.0000 - val_loss: 0.6276 - val_accuracy: 0.9074
# Epoch 87/100
# 7/7 [==============================] - 0s 32ms/step - loss: 2.8868e-04 - accuracy: 1.0000 - val_loss: 0.6301 - val_accuracy: 0.9074
# Epoch 88/100
# 7/7 [==============================] - 0s 37ms/step - loss: 2.8288e-04 - accuracy: 1.0000 - val_loss: 0.6327 - val_accuracy: 0.9074
# Epoch 89/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.2193e-04 - accuracy: 1.0000 - val_loss: 0.6350 - val_accuracy: 0.9074
# Epoch 90/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.2076e-04 - accuracy: 1.0000 - val_loss: 0.6369 - val_accuracy: 0.9074
# Epoch 91/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.7612e-04 - accuracy: 1.0000 - val_loss: 0.6390 - val_accuracy: 0.9074
# Epoch 92/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.6454e-04 - accuracy: 1.0000 - val_loss: 0.6408 - val_accuracy: 0.9074
# Epoch 93/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.4037e-04 - accuracy: 1.0000 - val_loss: 0.6443 - val_accuracy: 0.9074
# Epoch 94/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.1028e-04 - accuracy: 1.0000 - val_loss: 0.6527 - val_accuracy: 0.9074
# Epoch 95/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.0951e-04 - accuracy: 1.0000 - val_loss: 0.6566 - val_accuracy: 0.9074
# Epoch 96/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.1797e-04 - accuracy: 1.0000 - val_loss: 0.6593 - val_accuracy: 0.9074
# Epoch 97/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.7806e-04 - accuracy: 1.0000 - val_loss: 0.6615 - val_accuracy: 0.9074
# Epoch 98/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.1128e-04 - accuracy: 1.0000 - val_loss: 0.6633 - val_accuracy: 0.9074
# Epoch 99/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.4873e-04 - accuracy: 1.0000 - val_loss: 0.6652 - val_accuracy: 0.9074
# Epoch 100/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.2841e-04 - accuracy: 1.0000 - val_loss: 0.6671 - val_accuracy: 0.9074
# Test loss: 0.5555381774902344
# Test accuracy: 0.9259259104728699
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B27CA65310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       119
#            1       0.69      0.69      0.69        16
#
#     accuracy                           0.93       135
#    macro avg       0.82      0.82      0.82       135
# weighted avg       0.93      0.93      0.93       135
#
# [[114   5]
#  [  5  11]]

# %%
model2.save('s_a_p.h5')
