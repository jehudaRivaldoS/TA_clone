# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('d_sa_t.csv')

# %%
count_label = dsa['Kuliner'].value_counts()

# Membuat diagram batang
plt.bar(count_label.index, count_label.values)
plt.xticks([0, 1])
plt.xlabel('Label')
plt.ylabel('Jumlah Data')
plt.title('Distribusi Label pada Dataset')
plt.show()

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Kuliner']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 280ms/step - loss: 0.6646 - accuracy: 0.7309 - val_loss: 0.5859 - val_accuracy: 0.8426
# Epoch 2/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.5116 - accuracy: 0.8074 - val_loss: 0.4149 - val_accuracy: 0.8426
# Epoch 3/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4608 - accuracy: 0.8074 - val_loss: 0.4167 - val_accuracy: 0.8426
# Epoch 4/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.4468 - accuracy: 0.8074 - val_loss: 0.4080 - val_accuracy: 0.8426
# Epoch 5/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.4356 - accuracy: 0.8074 - val_loss: 0.3864 - val_accuracy: 0.8426
# Epoch 6/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4228 - accuracy: 0.8074 - val_loss: 0.3954 - val_accuracy: 0.8426
# Epoch 7/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.4049 - accuracy: 0.8074 - val_loss: 0.3597 - val_accuracy: 0.8426
# Epoch 8/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.3782 - accuracy: 0.8074 - val_loss: 0.3389 - val_accuracy: 0.8426
# Epoch 9/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.3344 - accuracy: 0.8074 - val_loss: 0.2927 - val_accuracy: 0.8611
# Epoch 10/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.2553 - accuracy: 0.8956 - val_loss: 0.2331 - val_accuracy: 0.9074
# Epoch 11/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.1627 - accuracy: 0.9443 - val_loss: 0.2756 - val_accuracy: 0.8981
# Epoch 12/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.1118 - accuracy: 0.9652 - val_loss: 0.2498 - val_accuracy: 0.9259
# Epoch 13/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.2126 - val_accuracy: 0.9352
# Epoch 14/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0472 - accuracy: 0.9907 - val_loss: 0.1847 - val_accuracy: 0.9444
# Epoch 15/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0355 - accuracy: 0.9930 - val_loss: 0.2029 - val_accuracy: 0.9074
# Epoch 16/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0394 - accuracy: 0.9930 - val_loss: 0.1510 - val_accuracy: 0.9352
# Epoch 17/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0378 - accuracy: 0.9930 - val_loss: 0.1383 - val_accuracy: 0.9259
# Epoch 18/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0196 - accuracy: 0.9954 - val_loss: 0.1349 - val_accuracy: 0.9352
# Epoch 19/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9444
# Epoch 20/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9352
# Epoch 21/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0127 - accuracy: 0.9977 - val_loss: 0.4897 - val_accuracy: 0.8611
# Epoch 22/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0260 - accuracy: 0.9907 - val_loss: 0.3135 - val_accuracy: 0.9444
# Epoch 23/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0169 - accuracy: 0.9930 - val_loss: 0.2256 - val_accuracy: 0.9537
# Epoch 24/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0160 - accuracy: 0.9954 - val_loss: 0.2484 - val_accuracy: 0.9444
# Epoch 25/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0132 - accuracy: 0.9977 - val_loss: 0.2633 - val_accuracy: 0.9352
# Epoch 26/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0109 - accuracy: 0.9977 - val_loss: 0.2724 - val_accuracy: 0.9444
# Epoch 27/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0041 - accuracy: 0.9977 - val_loss: 0.2300 - val_accuracy: 0.9537
# Epoch 28/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0116 - accuracy: 0.9954 - val_loss: 0.3550 - val_accuracy: 0.9167
# Epoch 29/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0344 - accuracy: 0.9907 - val_loss: 0.3222 - val_accuracy: 0.9352
# Epoch 30/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0196 - accuracy: 0.9954 - val_loss: 0.2607 - val_accuracy: 0.9352
# Epoch 31/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0151 - accuracy: 0.9977 - val_loss: 0.3478 - val_accuracy: 0.9259
# Epoch 32/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3541 - val_accuracy: 0.9259
# Epoch 33/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.3716 - val_accuracy: 0.9259
# Epoch 34/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3852 - val_accuracy: 0.9259
# Epoch 35/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3846 - val_accuracy: 0.9259
# Epoch 36/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3962 - val_accuracy: 0.9259
# Epoch 37/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4024 - val_accuracy: 0.9259
# Epoch 38/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4093 - val_accuracy: 0.9259
# Epoch 39/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3952 - val_accuracy: 0.9259
# Epoch 40/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.9259
# Epoch 41/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4157 - val_accuracy: 0.9259
# Epoch 42/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.9167
# Epoch 43/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4049 - val_accuracy: 0.9167
# Epoch 44/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3985 - val_accuracy: 0.9167
# Epoch 45/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.9167
# Epoch 46/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0237 - accuracy: 0.9907 - val_loss: 0.4019 - val_accuracy: 0.9259
# Epoch 47/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.3115 - val_accuracy: 0.9444
# Epoch 48/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9444
# Epoch 49/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3477 - val_accuracy: 0.9352
# Epoch 50/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3343 - val_accuracy: 0.9444
# Epoch 51/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3310 - val_accuracy: 0.9444
# Epoch 52/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3337 - val_accuracy: 0.9444
# Epoch 53/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3389 - val_accuracy: 0.9444
# Epoch 54/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3490 - val_accuracy: 0.9352
# Epoch 55/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3565 - val_accuracy: 0.9352
# Epoch 56/100
# 7/7 [==============================] - 0s 34ms/step - loss: 9.8739e-04 - accuracy: 1.0000 - val_loss: 0.3605 - val_accuracy: 0.9352
# Epoch 57/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9352
# Epoch 58/100
# 7/7 [==============================] - 0s 36ms/step - loss: 8.0599e-04 - accuracy: 1.0000 - val_loss: 0.3659 - val_accuracy: 0.9352
# Epoch 59/100
# 7/7 [==============================] - 0s 34ms/step - loss: 8.6746e-04 - accuracy: 1.0000 - val_loss: 0.3676 - val_accuracy: 0.9352
# Epoch 60/100
# 7/7 [==============================] - 0s 34ms/step - loss: 7.8155e-04 - accuracy: 1.0000 - val_loss: 0.3653 - val_accuracy: 0.9352
# Epoch 61/100
# 7/7 [==============================] - 0s 35ms/step - loss: 6.9815e-04 - accuracy: 1.0000 - val_loss: 0.3648 - val_accuracy: 0.9352
# Epoch 62/100
# 7/7 [==============================] - 0s 35ms/step - loss: 8.7495e-04 - accuracy: 1.0000 - val_loss: 0.3651 - val_accuracy: 0.9352
# Epoch 63/100
# 7/7 [==============================] - 0s 33ms/step - loss: 7.4077e-04 - accuracy: 1.0000 - val_loss: 0.3655 - val_accuracy: 0.9352
# Epoch 64/100
# 7/7 [==============================] - 0s 34ms/step - loss: 8.8556e-04 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.9352
# Epoch 65/100
# 7/7 [==============================] - 0s 34ms/step - loss: 7.2112e-04 - accuracy: 1.0000 - val_loss: 0.3683 - val_accuracy: 0.9352
# Epoch 66/100
# 7/7 [==============================] - 0s 35ms/step - loss: 6.9912e-04 - accuracy: 1.0000 - val_loss: 0.3688 - val_accuracy: 0.9352
# Epoch 67/100
# 7/7 [==============================] - 0s 34ms/step - loss: 6.3647e-04 - accuracy: 1.0000 - val_loss: 0.3724 - val_accuracy: 0.9352
# Epoch 68/100
# 7/7 [==============================] - 0s 34ms/step - loss: 7.4400e-04 - accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.9352
# Epoch 69/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.4189e-04 - accuracy: 1.0000 - val_loss: 0.3784 - val_accuracy: 0.9352
# Epoch 70/100
# 7/7 [==============================] - 0s 34ms/step - loss: 6.1748e-04 - accuracy: 1.0000 - val_loss: 0.3802 - val_accuracy: 0.9352
# Epoch 71/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.8360e-04 - accuracy: 1.0000 - val_loss: 0.3819 - val_accuracy: 0.9352
# Epoch 72/100
# 7/7 [==============================] - 0s 34ms/step - loss: 7.3667e-04 - accuracy: 1.0000 - val_loss: 0.3864 - val_accuracy: 0.9352
# Epoch 73/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.5289e-04 - accuracy: 1.0000 - val_loss: 0.3903 - val_accuracy: 0.9352
# Epoch 74/100
# 7/7 [==============================] - 0s 33ms/step - loss: 4.4553e-04 - accuracy: 1.0000 - val_loss: 0.3922 - val_accuracy: 0.9352
# Epoch 75/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.2886e-04 - accuracy: 1.0000 - val_loss: 0.3936 - val_accuracy: 0.9352
# Epoch 76/100
# 7/7 [==============================] - 0s 35ms/step - loss: 5.4261e-04 - accuracy: 1.0000 - val_loss: 0.3940 - val_accuracy: 0.9352
# Epoch 77/100
# 7/7 [==============================] - 0s 35ms/step - loss: 5.2291e-04 - accuracy: 1.0000 - val_loss: 0.3937 - val_accuracy: 0.9352
# Epoch 78/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.1281e-04 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.9352
# Epoch 79/100
# 7/7 [==============================] - 0s 35ms/step - loss: 5.3073e-04 - accuracy: 1.0000 - val_loss: 0.3926 - val_accuracy: 0.9352
# Epoch 80/100
# 7/7 [==============================] - 0s 33ms/step - loss: 6.9869e-04 - accuracy: 1.0000 - val_loss: 0.3899 - val_accuracy: 0.9352
# Epoch 81/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.4948e-04 - accuracy: 1.0000 - val_loss: 0.3888 - val_accuracy: 0.9352
# Epoch 82/100
# 7/7 [==============================] - 0s 33ms/step - loss: 4.0047e-04 - accuracy: 1.0000 - val_loss: 0.3887 - val_accuracy: 0.9352
# Epoch 83/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.8817e-04 - accuracy: 1.0000 - val_loss: 0.3883 - val_accuracy: 0.9352
# Epoch 84/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.6115e-04 - accuracy: 1.0000 - val_loss: 0.3904 - val_accuracy: 0.9352
# Epoch 85/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.7383e-04 - accuracy: 1.0000 - val_loss: 0.3906 - val_accuracy: 0.9352
# Epoch 86/100
# 7/7 [==============================] - 0s 35ms/step - loss: 3.1054e-04 - accuracy: 1.0000 - val_loss: 0.3904 - val_accuracy: 0.9352
# Epoch 87/100
# 7/7 [==============================] - 0s 35ms/step - loss: 4.4891e-04 - accuracy: 1.0000 - val_loss: 0.3907 - val_accuracy: 0.9352
# Epoch 88/100
# 7/7 [==============================] - 0s 35ms/step - loss: 3.6034e-04 - accuracy: 1.0000 - val_loss: 0.3913 - val_accuracy: 0.9352
# Epoch 89/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.5696e-04 - accuracy: 1.0000 - val_loss: 0.3917 - val_accuracy: 0.9352
# Epoch 90/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.5799e-04 - accuracy: 1.0000 - val_loss: 0.3922 - val_accuracy: 0.9352
# Epoch 91/100
# 7/7 [==============================] - 0s 33ms/step - loss: 3.6838e-04 - accuracy: 1.0000 - val_loss: 0.3926 - val_accuracy: 0.9352
# Epoch 92/100
# 7/7 [==============================] - 0s 35ms/step - loss: 3.3965e-04 - accuracy: 1.0000 - val_loss: 0.3928 - val_accuracy: 0.9352
# Epoch 93/100
# 7/7 [==============================] - 0s 35ms/step - loss: 2.3564e-04 - accuracy: 1.0000 - val_loss: 0.3929 - val_accuracy: 0.9352
# Epoch 94/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.6524e-04 - accuracy: 1.0000 - val_loss: 0.3917 - val_accuracy: 0.9352
# Epoch 95/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.8096e-04 - accuracy: 1.0000 - val_loss: 0.3914 - val_accuracy: 0.9352
# Epoch 96/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.4691e-04 - accuracy: 1.0000 - val_loss: 0.3916 - val_accuracy: 0.9352
# Epoch 97/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.9961e-04 - accuracy: 1.0000 - val_loss: 0.3920 - val_accuracy: 0.9352
# Epoch 98/100
# 7/7 [==============================] - 0s 33ms/step - loss: 3.4611e-04 - accuracy: 1.0000 - val_loss: 0.3916 - val_accuracy: 0.9352
# Epoch 99/100
# 7/7 [==============================] - 0s 33ms/step - loss: 4.2607e-04 - accuracy: 1.0000 - val_loss: 0.3917 - val_accuracy: 0.9352
# Epoch 100/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.2480e-04 - accuracy: 1.0000 - val_loss: 0.3968 - val_accuracy: 0.9352
# Test loss: 0.45733195543289185
# Test accuracy: 0.9333333373069763
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       110
#            1       0.81      0.84      0.82        25
#
#     accuracy                           0.93       135
#    macro avg       0.89      0.90      0.89       135
# weighted avg       0.93      0.93      0.93       135
#
# [[105   5]
#  [  4  21]]

# %%
# SA
# Preprocess data
ts = ["Tempat nya bersih", "cafe enak murah", "wisata tutup hujan becek", "makanan enak"]
t=[0,1,0,1]
tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(dsa['Ulasan'].astype(str))
X = tokenizer.texts_to_sequences(ts)
X = pad_sequences(X, maxlen=50, padding='post')

# Make predictions
predictions = model2.predict(X)
rounded_predictions = np.round(predictions).astype(int)

accuracy = accuracy_score(t, rounded_predictions)
report = classification_report(t, rounded_predictions)
cm = confusion_matrix(t, rounded_predictions)

print('Accuracy:', accuracy)
print(cm)
print(report)
# Out:
# Accuracy: 0.5
# [[2 0]
#  [2 0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.50         4
#    macro avg       0.25      0.50      0.33         4
# weighted avg       0.25      0.50      0.33         4
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model2.save('sa_k_dt.h5')
