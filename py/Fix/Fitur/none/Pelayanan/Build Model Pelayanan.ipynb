# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('d_sa.csv')

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Pelayanan']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 284ms/step - loss: 0.6454 - accuracy: 0.8121 - val_loss: 0.5290 - val_accuracy: 0.9259
# Epoch 2/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.3834 - accuracy: 0.9049 - val_loss: 0.2340 - val_accuracy: 0.9259
# Epoch 3/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.3353 - accuracy: 0.9049 - val_loss: 0.2471 - val_accuracy: 0.9259
# Epoch 4/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.3049 - accuracy: 0.9049 - val_loss: 0.2360 - val_accuracy: 0.9259
# Epoch 5/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2866 - accuracy: 0.9049 - val_loss: 0.2311 - val_accuracy: 0.9259
# Epoch 6/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2670 - accuracy: 0.9049 - val_loss: 0.2175 - val_accuracy: 0.9259
# Epoch 7/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.2646 - accuracy: 0.9049 - val_loss: 0.2154 - val_accuracy: 0.9259
# Epoch 8/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2558 - accuracy: 0.9049 - val_loss: 0.2157 - val_accuracy: 0.9259
# Epoch 9/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2379 - accuracy: 0.9049 - val_loss: 0.2186 - val_accuracy: 0.9259
# Epoch 10/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2230 - accuracy: 0.9049 - val_loss: 0.2192 - val_accuracy: 0.9259
# Epoch 11/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2009 - accuracy: 0.9049 - val_loss: 0.2164 - val_accuracy: 0.9352
# Epoch 12/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.1737 - accuracy: 0.9234 - val_loss: 0.2117 - val_accuracy: 0.9352
# Epoch 13/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1134 - accuracy: 0.9559 - val_loss: 0.2211 - val_accuracy: 0.9259
# Epoch 14/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0688 - accuracy: 0.9791 - val_loss: 0.2295 - val_accuracy: 0.9444
# Epoch 15/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0503 - accuracy: 0.9791 - val_loss: 0.2580 - val_accuracy: 0.9352
# Epoch 16/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0288 - accuracy: 0.9954 - val_loss: 0.2864 - val_accuracy: 0.9537
# Epoch 17/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0269 - accuracy: 0.9930 - val_loss: 0.3058 - val_accuracy: 0.9352
# Epoch 18/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0173 - accuracy: 0.9954 - val_loss: 0.3229 - val_accuracy: 0.9352
# Epoch 19/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0291 - accuracy: 0.9930 - val_loss: 0.3035 - val_accuracy: 0.9352
# Epoch 20/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0220 - accuracy: 0.9930 - val_loss: 0.2904 - val_accuracy: 0.9444
# Epoch 21/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0253 - accuracy: 0.9954 - val_loss: 0.2672 - val_accuracy: 0.9537
# Epoch 22/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0367 - accuracy: 0.9884 - val_loss: 0.2448 - val_accuracy: 0.9537
# Epoch 23/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0277 - accuracy: 0.9907 - val_loss: 0.2134 - val_accuracy: 0.9537
# Epoch 24/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0349 - accuracy: 0.9861 - val_loss: 0.1839 - val_accuracy: 0.9537
# Epoch 25/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0259 - accuracy: 0.9954 - val_loss: 0.2412 - val_accuracy: 0.9444
# Epoch 26/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0308 - accuracy: 0.9954 - val_loss: 0.3029 - val_accuracy: 0.9259
# Epoch 27/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0246 - accuracy: 0.9954 - val_loss: 0.3215 - val_accuracy: 0.9167
# Epoch 28/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0205 - accuracy: 0.9954 - val_loss: 0.3181 - val_accuracy: 0.9167
# Epoch 29/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0228 - accuracy: 0.9954 - val_loss: 0.2993 - val_accuracy: 0.9259
# Epoch 30/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.3241 - val_accuracy: 0.9074
# Epoch 31/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.2878 - val_accuracy: 0.9352
# Epoch 32/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0172 - accuracy: 0.9954 - val_loss: 0.2794 - val_accuracy: 0.9444
# Epoch 33/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.2832 - val_accuracy: 0.9352
# Epoch 34/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.2660 - val_accuracy: 0.9444
# Epoch 35/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.2709 - val_accuracy: 0.9444
# Epoch 36/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0099 - accuracy: 0.9954 - val_loss: 0.2890 - val_accuracy: 0.9444
# Epoch 37/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 0.2801 - val_accuracy: 0.9444
# Epoch 38/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0289 - accuracy: 0.9907 - val_loss: 0.2503 - val_accuracy: 0.9444
# Epoch 39/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0224 - accuracy: 0.9954 - val_loss: 0.2170 - val_accuracy: 0.9444
# Epoch 40/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0149 - accuracy: 0.9954 - val_loss: 0.2225 - val_accuracy: 0.9444
# Epoch 41/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.2342 - val_accuracy: 0.9444
# Epoch 42/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0174 - accuracy: 0.9930 - val_loss: 0.2312 - val_accuracy: 0.9444
# Epoch 43/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0176 - accuracy: 0.9884 - val_loss: 0.2253 - val_accuracy: 0.9537
# Epoch 44/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0102 - accuracy: 0.9954 - val_loss: 0.2264 - val_accuracy: 0.9537
# Epoch 45/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0100 - accuracy: 0.9930 - val_loss: 0.2308 - val_accuracy: 0.9537
# Epoch 46/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.2566 - val_accuracy: 0.9537
# Epoch 47/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.2320 - val_accuracy: 0.9537
# Epoch 48/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0172 - accuracy: 0.9930 - val_loss: 0.2032 - val_accuracy: 0.9537
# Epoch 49/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0122 - accuracy: 0.9954 - val_loss: 0.2439 - val_accuracy: 0.9537
# Epoch 50/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0092 - accuracy: 0.9954 - val_loss: 0.2697 - val_accuracy: 0.9630
# Epoch 51/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0077 - accuracy: 0.9930 - val_loss: 0.2758 - val_accuracy: 0.9630
# Epoch 52/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0129 - accuracy: 0.9930 - val_loss: 0.2755 - val_accuracy: 0.9630
# Epoch 53/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.2798 - val_accuracy: 0.9630
# Epoch 54/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0092 - accuracy: 0.9930 - val_loss: 0.2831 - val_accuracy: 0.9630
# Epoch 55/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0084 - accuracy: 0.9954 - val_loss: 0.2834 - val_accuracy: 0.9630
# Epoch 56/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.2800 - val_accuracy: 0.9630
# Epoch 57/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.2802 - val_accuracy: 0.9630
# Epoch 58/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0092 - accuracy: 0.9907 - val_loss: 0.2839 - val_accuracy: 0.9630
# Epoch 59/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0097 - accuracy: 0.9930 - val_loss: 0.2836 - val_accuracy: 0.9630
# Epoch 60/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.2899 - val_accuracy: 0.9630
# Epoch 61/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0091 - accuracy: 0.9930 - val_loss: 0.2910 - val_accuracy: 0.9630
# Epoch 62/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0073 - accuracy: 0.9930 - val_loss: 0.2934 - val_accuracy: 0.9630
# Epoch 63/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0079 - accuracy: 0.9930 - val_loss: 0.2870 - val_accuracy: 0.9630
# Epoch 64/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0067 - accuracy: 0.9954 - val_loss: 0.2839 - val_accuracy: 0.9630
# Epoch 65/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0090 - accuracy: 0.9954 - val_loss: 0.2872 - val_accuracy: 0.9630
# Epoch 66/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0072 - accuracy: 0.9954 - val_loss: 0.2817 - val_accuracy: 0.9630
# Epoch 67/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2840 - val_accuracy: 0.9630
# Epoch 68/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0073 - accuracy: 0.9954 - val_loss: 0.2885 - val_accuracy: 0.9630
# Epoch 69/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0089 - accuracy: 0.9930 - val_loss: 0.2828 - val_accuracy: 0.9630
# Epoch 70/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.2801 - val_accuracy: 0.9630
# Epoch 71/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0087 - accuracy: 0.9954 - val_loss: 0.2833 - val_accuracy: 0.9630
# Epoch 72/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0069 - accuracy: 0.9954 - val_loss: 0.2899 - val_accuracy: 0.9630
# Epoch 73/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0078 - accuracy: 0.9930 - val_loss: 0.2998 - val_accuracy: 0.9630
# Epoch 74/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0082 - accuracy: 0.9954 - val_loss: 0.3014 - val_accuracy: 0.9630
# Epoch 75/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0075 - accuracy: 0.9954 - val_loss: 0.3024 - val_accuracy: 0.9630
# Epoch 76/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0077 - accuracy: 0.9954 - val_loss: 0.2924 - val_accuracy: 0.9630
# Epoch 77/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0081 - accuracy: 0.9930 - val_loss: 0.2829 - val_accuracy: 0.9630
# Epoch 78/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9630
# Epoch 79/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0067 - accuracy: 0.9954 - val_loss: 0.2864 - val_accuracy: 0.9630
# Epoch 80/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0095 - accuracy: 0.9907 - val_loss: 0.2928 - val_accuracy: 0.9630
# Epoch 81/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.2927 - val_accuracy: 0.9630
# Epoch 82/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 0.2989 - val_accuracy: 0.9630
# Epoch 83/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0103 - accuracy: 0.9907 - val_loss: 0.2952 - val_accuracy: 0.9630
# Epoch 84/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0073 - accuracy: 0.9930 - val_loss: 0.2953 - val_accuracy: 0.9630
# Epoch 85/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.2960 - val_accuracy: 0.9630
# Epoch 86/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.2964 - val_accuracy: 0.9630
# Epoch 87/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0076 - accuracy: 0.9954 - val_loss: 0.2987 - val_accuracy: 0.9630
# Epoch 88/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0071 - accuracy: 0.9954 - val_loss: 0.2945 - val_accuracy: 0.9630
# Epoch 89/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0074 - accuracy: 0.9954 - val_loss: 0.2917 - val_accuracy: 0.9630
# Epoch 90/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0069 - accuracy: 0.9954 - val_loss: 0.2918 - val_accuracy: 0.9630
# Epoch 91/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.2961 - val_accuracy: 0.9630
# Epoch 92/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0081 - accuracy: 0.9954 - val_loss: 0.3022 - val_accuracy: 0.9630
# Epoch 93/100
# 5/7 [====================>.........] - ETA: 0s - loss: 0.0108 - accuracy: 0.9906

# %%
# SA
# Preprocess data
ts = ["layan baik tugas sopan", "tempat alami sejuk tiket masuk wahana murah riah", "wisata tutup", "anak recomend layan baik"]
t=[1,0,0,1]
tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(dsa['Ulasan'].astype(str))
X = tokenizer.texts_to_sequences(ts)
X = pad_sequences(X, maxlen=50, padding='post')

# Make predictions
predictions = model2.predict(X)
rounded_predictions = np.round(predictions).astype(int)

accuracy = accuracy_score(t, rounded_predictions)
report = classification_report(t, rounded_predictions)
cm = confusion_matrix(t, rounded_predictions)

print('Accuracy:', accuracy)
print(cm)
print(report)
# Out:
# Accuracy: 1.0
# [[2 0]
#  [0 2]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %%
model2.save('sa_p.h5')
