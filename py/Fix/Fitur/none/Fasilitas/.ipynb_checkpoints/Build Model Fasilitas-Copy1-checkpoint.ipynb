# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('data_ap_s_a_f.csv')

# %%
count_label = dsa['Fasilitas'].value_counts()

# Membuat diagram batang
plt.bar(count_label.index, count_label.values)
plt.xticks([0, 1])
plt.xlabel('Label')
plt.ylabel('Jumlah Data')
plt.title('Distribusi Label pada Dataset')
plt.show()

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Fasilitas']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 226ms/step - loss: 0.6917 - accuracy: 0.5638 - val_loss: 0.6867 - val_accuracy: 0.5741
# Epoch 2/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.6825 - accuracy: 0.5754 - val_loss: 0.6775 - val_accuracy: 0.5741
# Epoch 3/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6664 - accuracy: 0.5754 - val_loss: 0.6499 - val_accuracy: 0.5741
# Epoch 4/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6235 - accuracy: 0.5754 - val_loss: 0.5893 - val_accuracy: 0.5741
# Epoch 5/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5681 - accuracy: 0.5940 - val_loss: 0.5617 - val_accuracy: 0.7130
# Epoch 6/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5107 - accuracy: 0.7889 - val_loss: 0.5529 - val_accuracy: 0.7037
# Epoch 7/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3892 - accuracy: 0.8585 - val_loss: 0.7321 - val_accuracy: 0.7407
# Epoch 8/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2782 - accuracy: 0.9049 - val_loss: 0.6001 - val_accuracy: 0.7778
# Epoch 9/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2100 - accuracy: 0.9327 - val_loss: 0.6570 - val_accuracy: 0.7315
# Epoch 10/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.2048 - accuracy: 0.9234 - val_loss: 0.7176 - val_accuracy: 0.7778
# Epoch 11/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1478 - accuracy: 0.9582 - val_loss: 0.7167 - val_accuracy: 0.7778
# Epoch 12/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1183 - accuracy: 0.9698 - val_loss: 0.8467 - val_accuracy: 0.8056
# Epoch 13/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1048 - accuracy: 0.9768 - val_loss: 0.7959 - val_accuracy: 0.7778
# Epoch 14/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0817 - accuracy: 0.9838 - val_loss: 0.8923 - val_accuracy: 0.7870
# Epoch 15/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0817 - accuracy: 0.9838 - val_loss: 0.9415 - val_accuracy: 0.7685
# Epoch 16/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0678 - accuracy: 0.9884 - val_loss: 0.9741 - val_accuracy: 0.7407
# Epoch 17/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0715 - accuracy: 0.9861 - val_loss: 0.9485 - val_accuracy: 0.7500
# Epoch 18/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0827 - accuracy: 0.9838 - val_loss: 0.9332 - val_accuracy: 0.7407
# Epoch 19/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0845 - accuracy: 0.9838 - val_loss: 0.9940 - val_accuracy: 0.7315
# Epoch 20/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0731 - accuracy: 0.9814 - val_loss: 0.8703 - val_accuracy: 0.7778
# Epoch 21/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0622 - accuracy: 0.9814 - val_loss: 0.7937 - val_accuracy: 0.7500
# Epoch 22/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0667 - accuracy: 0.9675 - val_loss: 0.9060 - val_accuracy: 0.7593
# Epoch 23/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0584 - accuracy: 0.9884 - val_loss: 1.0963 - val_accuracy: 0.7407
# Epoch 24/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0375 - accuracy: 0.9907 - val_loss: 1.1957 - val_accuracy: 0.7500
# Epoch 25/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0439 - accuracy: 0.9884 - val_loss: 1.1662 - val_accuracy: 0.7130
# Epoch 26/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.2062 - accuracy: 0.9258 - val_loss: 0.6167 - val_accuracy: 0.7315
# Epoch 27/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1347 - accuracy: 0.9629 - val_loss: 0.7247 - val_accuracy: 0.7407
# Epoch 28/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0772 - accuracy: 0.9861 - val_loss: 0.7464 - val_accuracy: 0.7407
# Epoch 29/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0731 - accuracy: 0.9768 - val_loss: 0.8819 - val_accuracy: 0.7407
# Epoch 30/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0564 - accuracy: 0.9884 - val_loss: 0.9978 - val_accuracy: 0.7500
# Epoch 31/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0462 - accuracy: 0.9884 - val_loss: 1.0975 - val_accuracy: 0.7593
# Epoch 32/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0370 - accuracy: 0.9930 - val_loss: 1.1584 - val_accuracy: 0.7500
# Epoch 33/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0321 - accuracy: 0.9930 - val_loss: 1.1585 - val_accuracy: 0.7593
# Epoch 34/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0347 - accuracy: 0.9930 - val_loss: 1.1612 - val_accuracy: 0.7685
# Epoch 35/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0249 - accuracy: 0.9954 - val_loss: 1.2243 - val_accuracy: 0.7407
# Epoch 36/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0180 - accuracy: 0.9954 - val_loss: 1.3251 - val_accuracy: 0.7315
# Epoch 37/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 1.3554 - val_accuracy: 0.7315
# Epoch 38/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0181 - accuracy: 0.9954 - val_loss: 1.4188 - val_accuracy: 0.7315
# Epoch 39/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 1.4545 - val_accuracy: 0.7315
# Epoch 40/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0187 - accuracy: 0.9954 - val_loss: 1.4605 - val_accuracy: 0.7315
# Epoch 41/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 1.4744 - val_accuracy: 0.7315
# Epoch 42/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 1.4907 - val_accuracy: 0.7315
# Epoch 43/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0211 - accuracy: 0.9954 - val_loss: 1.4883 - val_accuracy: 0.7315
# Epoch 44/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0126 - accuracy: 0.9954 - val_loss: 1.5253 - val_accuracy: 0.7315
# Epoch 45/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0178 - accuracy: 0.9954 - val_loss: 1.5196 - val_accuracy: 0.7315
# Epoch 46/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0149 - accuracy: 0.9977 - val_loss: 1.5213 - val_accuracy: 0.7315
# Epoch 47/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0167 - accuracy: 0.9954 - val_loss: 1.5640 - val_accuracy: 0.7315
# Epoch 48/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 1.6679 - val_accuracy: 0.7037
# Epoch 49/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0175 - accuracy: 0.9954 - val_loss: 1.7214 - val_accuracy: 0.7130
# Epoch 50/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0217 - accuracy: 0.9861 - val_loss: 1.8190 - val_accuracy: 0.7037
# Epoch 51/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0091 - accuracy: 0.9954 - val_loss: 1.8652 - val_accuracy: 0.7037
# Epoch 52/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 1.8856 - val_accuracy: 0.7037
# Epoch 53/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.8928 - val_accuracy: 0.7037
# Epoch 54/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 1.9091 - val_accuracy: 0.7037
# Epoch 55/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 2.0340 - val_accuracy: 0.7037
# Epoch 56/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0124 - accuracy: 0.9930 - val_loss: 2.0836 - val_accuracy: 0.7130
# Epoch 57/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0127 - accuracy: 0.9977 - val_loss: 2.0557 - val_accuracy: 0.7130
# Epoch 58/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 1.9501 - val_accuracy: 0.7130
# Epoch 59/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 1.9834 - val_accuracy: 0.7037
# Epoch 60/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0185 - accuracy: 0.9930 - val_loss: 2.0429 - val_accuracy: 0.7037
# Epoch 61/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 1.8534 - val_accuracy: 0.7130
# Epoch 62/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 2.0631 - val_accuracy: 0.6944
# Epoch 63/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0239 - accuracy: 0.9907 - val_loss: 2.0674 - val_accuracy: 0.6944
# Epoch 64/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0172 - accuracy: 0.9930 - val_loss: 1.7728 - val_accuracy: 0.7222
# Epoch 65/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0272 - accuracy: 0.9930 - val_loss: 1.7890 - val_accuracy: 0.7130
# Epoch 66/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0205 - accuracy: 0.9954 - val_loss: 1.8936 - val_accuracy: 0.7037
# Epoch 67/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 1.8986 - val_accuracy: 0.7037
# Epoch 68/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0073 - accuracy: 0.9954 - val_loss: 1.9878 - val_accuracy: 0.7037
# Epoch 69/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0262 - accuracy: 0.9884 - val_loss: 2.0098 - val_accuracy: 0.7037
# Epoch 70/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0148 - accuracy: 0.9930 - val_loss: 2.0312 - val_accuracy: 0.6944
# Epoch 71/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 2.0028 - val_accuracy: 0.7037
# Epoch 72/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 2.1176 - val_accuracy: 0.6944
# Epoch 73/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0175 - accuracy: 0.9977 - val_loss: 2.2946 - val_accuracy: 0.6944
# Epoch 74/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0212 - accuracy: 0.9954 - val_loss: 2.2781 - val_accuracy: 0.6944
# Epoch 75/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0147 - accuracy: 0.9930 - val_loss: 2.2461 - val_accuracy: 0.6944
# Epoch 76/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0168 - accuracy: 0.9954 - val_loss: 2.1634 - val_accuracy: 0.6944
# Epoch 77/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0177 - accuracy: 0.9954 - val_loss: 2.0053 - val_accuracy: 0.7130
# Epoch 78/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0158 - accuracy: 0.9954 - val_loss: 1.9277 - val_accuracy: 0.7407
# Epoch 79/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 1.7533 - val_accuracy: 0.7500
# Epoch 80/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 1.7948 - val_accuracy: 0.7500
# Epoch 81/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 2.0248 - val_accuracy: 0.7315
# Epoch 82/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 2.0400 - val_accuracy: 0.7315
# Epoch 83/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0098 - accuracy: 0.9954 - val_loss: 1.9644 - val_accuracy: 0.7222
# Epoch 84/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0130 - accuracy: 0.9930 - val_loss: 1.8601 - val_accuracy: 0.7315
# Epoch 85/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0089 - accuracy: 0.9954 - val_loss: 2.0250 - val_accuracy: 0.7407
# Epoch 86/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0195 - accuracy: 0.9930 - val_loss: 2.0125 - val_accuracy: 0.7315
# Epoch 87/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 2.0394 - val_accuracy: 0.7315
# Epoch 88/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 2.0527 - val_accuracy: 0.7407
# Epoch 89/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0171 - accuracy: 0.9954 - val_loss: 2.0766 - val_accuracy: 0.7407
# Epoch 90/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0357 - accuracy: 0.9954 - val_loss: 1.9854 - val_accuracy: 0.7407
# Epoch 91/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0095 - accuracy: 0.9954 - val_loss: 1.8724 - val_accuracy: 0.7407
# Epoch 92/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0219 - accuracy: 0.9977 - val_loss: 1.8828 - val_accuracy: 0.7407
# Epoch 93/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0184 - accuracy: 0.9977 - val_loss: 1.8111 - val_accuracy: 0.7500
# Epoch 94/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 1.7724 - val_accuracy: 0.7407
# Epoch 95/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0171 - accuracy: 0.9977 - val_loss: 1.7253 - val_accuracy: 0.7593
# Epoch 96/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0229 - accuracy: 0.9954 - val_loss: 1.8422 - val_accuracy: 0.7315
# Epoch 97/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0591 - accuracy: 0.9884 - val_loss: 1.8022 - val_accuracy: 0.7222
# Epoch 98/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0368 - accuracy: 0.9907 - val_loss: 1.6100 - val_accuracy: 0.7315
# Epoch 99/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0254 - accuracy: 0.9930 - val_loss: 1.4291 - val_accuracy: 0.7222
# Epoch 100/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0388 - accuracy: 0.9884 - val_loss: 1.4056 - val_accuracy: 0.7407
# Test loss: 1.1644256114959717
# Test accuracy: 0.8074073791503906
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76        57
#            1       0.81      0.87      0.84        78
#
#     accuracy                           0.81       135
#    macro avg       0.81      0.80      0.80       135
# weighted avg       0.81      0.81      0.81       135
#
# [[41 16]
#  [10 68]]

# %%
# NA
# Preprocess data
data = ["toilet bagus", "layan tidak sopan", "pegawai tidak ramah", "makan enak", "tiket murah bagus","cafe enak bagus parkir sempit"]
label = [1,0,0,0,1,1]
tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(dsa['Ulasan'].astype(str))
X = tokenizer.texts_to_sequences(data)
X = pad_sequences(X, maxlen=50, padding='post')

# Make predictions
predictions = model2.predict(X)
rounded_predictions = np.round(predictions).astype(int)

accuracy = accuracy_score(label, rounded_predictions)
report = classification_report(label, rounded_predictions)
cm = confusion_matrix(label, rounded_predictions)

print('Accuracy:', accuracy)
print(cm)
print(report)
# Out:
# Accuracy: 1.0
# [[3 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %%
model2.save('s_a_fn.h5')
