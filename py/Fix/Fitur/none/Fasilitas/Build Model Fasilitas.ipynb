# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('d_sa.csv')

# %%
count_label = dsa['Fasilitas'].value_counts()

# Membuat diagram batang
plt.bar(count_label.index, count_label.values)
plt.xticks([0, 1])
plt.xlabel('Label')
plt.ylabel('Jumlah Data')
plt.title('Distribusi Label pada Dataset')
plt.show()

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Fasilitas']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 261ms/step - loss: 0.6913 - accuracy: 0.5290 - val_loss: 0.6845 - val_accuracy: 0.5556
# Epoch 2/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.6753 - accuracy: 0.5174 - val_loss: 0.6602 - val_accuracy: 0.5556
# Epoch 3/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.6529 - accuracy: 0.5684 - val_loss: 0.6420 - val_accuracy: 0.6296
# Epoch 4/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.6317 - accuracy: 0.6984 - val_loss: 0.6198 - val_accuracy: 0.7037
# Epoch 5/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.6080 - accuracy: 0.7494 - val_loss: 0.5914 - val_accuracy: 0.7130
# Epoch 6/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.5611 - accuracy: 0.7564 - val_loss: 0.5665 - val_accuracy: 0.7037
# Epoch 7/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5108 - accuracy: 0.7749 - val_loss: 0.5049 - val_accuracy: 0.7685
# Epoch 8/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.4229 - accuracy: 0.8353 - val_loss: 0.4286 - val_accuracy: 0.8241
# Epoch 9/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.3090 - accuracy: 0.9095 - val_loss: 0.3466 - val_accuracy: 0.8519
# Epoch 10/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1607 - accuracy: 0.9559 - val_loss: 0.4255 - val_accuracy: 0.8333
# Epoch 11/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1346 - accuracy: 0.9629 - val_loss: 0.4493 - val_accuracy: 0.8704
# Epoch 12/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0888 - accuracy: 0.9791 - val_loss: 0.4158 - val_accuracy: 0.8704
# Epoch 13/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0674 - accuracy: 0.9861 - val_loss: 0.4847 - val_accuracy: 0.8704
# Epoch 14/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0543 - accuracy: 0.9861 - val_loss: 0.4162 - val_accuracy: 0.8889
# Epoch 15/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0371 - accuracy: 0.9907 - val_loss: 0.4685 - val_accuracy: 0.8796
# Epoch 16/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0490 - accuracy: 0.9907 - val_loss: 0.5012 - val_accuracy: 0.8796
# Epoch 17/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0385 - accuracy: 0.9930 - val_loss: 0.4814 - val_accuracy: 0.8889
# Epoch 18/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0256 - accuracy: 0.9930 - val_loss: 0.4622 - val_accuracy: 0.8796
# Epoch 19/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0187 - accuracy: 0.9977 - val_loss: 0.4737 - val_accuracy: 0.8889
# Epoch 20/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0169 - accuracy: 0.9977 - val_loss: 0.4799 - val_accuracy: 0.8889
# Epoch 21/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0163 - accuracy: 0.9977 - val_loss: 0.4893 - val_accuracy: 0.8889
# Epoch 22/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0151 - accuracy: 0.9977 - val_loss: 0.4963 - val_accuracy: 0.8889
# Epoch 23/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0163 - accuracy: 0.9977 - val_loss: 0.5108 - val_accuracy: 0.8889
# Epoch 24/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0196 - accuracy: 0.9954 - val_loss: 0.5445 - val_accuracy: 0.8889
# Epoch 25/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0168 - accuracy: 0.9977 - val_loss: 0.5455 - val_accuracy: 0.8889
# Epoch 26/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0159 - accuracy: 0.9977 - val_loss: 0.5405 - val_accuracy: 0.8889
# Epoch 27/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0146 - accuracy: 0.9977 - val_loss: 0.5130 - val_accuracy: 0.8981
# Epoch 28/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0131 - accuracy: 0.9977 - val_loss: 0.4925 - val_accuracy: 0.9074
# Epoch 29/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0152 - accuracy: 0.9977 - val_loss: 0.4964 - val_accuracy: 0.9074
# Epoch 30/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0156 - accuracy: 0.9977 - val_loss: 0.5031 - val_accuracy: 0.9074
# Epoch 31/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0189 - accuracy: 0.9977 - val_loss: 0.5074 - val_accuracy: 0.9074
# Epoch 32/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0169 - accuracy: 0.9977 - val_loss: 0.5079 - val_accuracy: 0.9074
# Epoch 33/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0172 - accuracy: 0.9977 - val_loss: 0.5105 - val_accuracy: 0.9074
# Epoch 34/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0131 - accuracy: 0.9977 - val_loss: 0.5187 - val_accuracy: 0.9074
# Epoch 35/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0139 - accuracy: 0.9977 - val_loss: 0.5208 - val_accuracy: 0.8981
# Epoch 36/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0137 - accuracy: 0.9977 - val_loss: 0.5174 - val_accuracy: 0.9074
# Epoch 37/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0122 - accuracy: 0.9977 - val_loss: 0.5231 - val_accuracy: 0.9074
# Epoch 38/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0132 - accuracy: 0.9977 - val_loss: 0.5280 - val_accuracy: 0.8981
# Epoch 39/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0106 - accuracy: 0.9977 - val_loss: 0.5134 - val_accuracy: 0.9074
# Epoch 40/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0099 - accuracy: 0.9954 - val_loss: 0.5820 - val_accuracy: 0.8889
# Epoch 41/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.6682 - val_accuracy: 0.8611
# Epoch 42/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.6098 - val_accuracy: 0.8889
# Epoch 43/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0226 - accuracy: 0.9977 - val_loss: 0.5946 - val_accuracy: 0.8889
# Epoch 44/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0200 - accuracy: 0.9954 - val_loss: 0.6070 - val_accuracy: 0.8796
# Epoch 45/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.5909 - val_accuracy: 0.8796
# Epoch 46/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0058 - accuracy: 0.9954 - val_loss: 0.5818 - val_accuracy: 0.8889
# Epoch 47/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0051 - accuracy: 0.9977 - val_loss: 0.6096 - val_accuracy: 0.8796
# Epoch 48/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.6392 - val_accuracy: 0.8796
# Epoch 49/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0116 - accuracy: 0.9977 - val_loss: 0.6562 - val_accuracy: 0.8796
# Epoch 50/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0088 - accuracy: 0.9977 - val_loss: 0.6278 - val_accuracy: 0.8796
# Epoch 51/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0057 - accuracy: 0.9954 - val_loss: 0.6206 - val_accuracy: 0.8796
# Epoch 52/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.6276 - val_accuracy: 0.8796
# Epoch 53/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0072 - accuracy: 0.9954 - val_loss: 0.5422 - val_accuracy: 0.8889
# Epoch 54/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0200 - accuracy: 0.9977 - val_loss: 0.4687 - val_accuracy: 0.9167
# Epoch 55/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0233 - accuracy: 0.9977 - val_loss: 0.4748 - val_accuracy: 0.9167
# Epoch 56/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.4791 - val_accuracy: 0.9074
# Epoch 57/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0144 - accuracy: 0.9977 - val_loss: 0.4803 - val_accuracy: 0.9074
# Epoch 58/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0196 - accuracy: 0.9954 - val_loss: 0.4960 - val_accuracy: 0.8981
# Epoch 59/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.4787 - val_accuracy: 0.9074
# Epoch 60/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.5130 - val_accuracy: 0.9074
# Epoch 61/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.4756 - val_accuracy: 0.9167
# Epoch 62/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0125 - accuracy: 0.9977 - val_loss: 0.4899 - val_accuracy: 0.9167
# Epoch 63/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0199 - accuracy: 0.9977 - val_loss: 0.5063 - val_accuracy: 0.9074
# Epoch 64/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0198 - accuracy: 0.9977 - val_loss: 0.5318 - val_accuracy: 0.8981
# Epoch 65/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0141 - accuracy: 0.9977 - val_loss: 0.5644 - val_accuracy: 0.8889
# Epoch 66/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0048 - accuracy: 0.9977 - val_loss: 0.5912 - val_accuracy: 0.8796
# Epoch 67/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.5641 - val_accuracy: 0.8796
# Epoch 68/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.8796
# Epoch 69/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0064 - accuracy: 0.9954 - val_loss: 0.5086 - val_accuracy: 0.8889
# Epoch 70/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.5758 - val_accuracy: 0.8796
# Epoch 71/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0089 - accuracy: 0.9954 - val_loss: 0.6008 - val_accuracy: 0.8796
# Epoch 72/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0069 - accuracy: 0.9954 - val_loss: 0.6437 - val_accuracy: 0.8796
# Epoch 73/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0045 - accuracy: 0.9977 - val_loss: 0.6511 - val_accuracy: 0.8796
# Epoch 74/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0058 - accuracy: 0.9954 - val_loss: 0.6513 - val_accuracy: 0.8796
# Epoch 75/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.6467 - val_accuracy: 0.8796
# Epoch 76/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5871 - val_accuracy: 0.8889
# Epoch 77/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.5779 - val_accuracy: 0.8889
# Epoch 78/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0041 - accuracy: 0.9977 - val_loss: 0.5924 - val_accuracy: 0.8889
# Epoch 79/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0044 - accuracy: 0.9977 - val_loss: 0.6138 - val_accuracy: 0.8889
# Epoch 80/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0044 - accuracy: 0.9977 - val_loss: 0.6384 - val_accuracy: 0.8889
# Epoch 81/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0046 - accuracy: 0.9954 - val_loss: 0.6504 - val_accuracy: 0.8889
# Epoch 82/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6646 - val_accuracy: 0.8889
# Epoch 83/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0051 - accuracy: 0.9977 - val_loss: 0.6737 - val_accuracy: 0.8889
# Epoch 84/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.6668 - val_accuracy: 0.8889
# Epoch 85/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0046 - accuracy: 0.9977 - val_loss: 0.6615 - val_accuracy: 0.8889
# Epoch 86/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6714 - val_accuracy: 0.8889
# Epoch 87/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.6803 - val_accuracy: 0.8796
# Epoch 88/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.6781 - val_accuracy: 0.8889
# Epoch 89/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6646 - val_accuracy: 0.8889
# Epoch 90/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.6643 - val_accuracy: 0.8889
# Epoch 91/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.6650 - val_accuracy: 0.8889
# Epoch 92/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0030 - accuracy: 0.9977 - val_loss: 0.6724 - val_accuracy: 0.8889
# Epoch 93/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0060 - accuracy: 0.9954 - val_loss: 0.6792 - val_accuracy: 0.8889
# Epoch 94/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6781 - val_accuracy: 0.8889
# Epoch 95/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6859 - val_accuracy: 0.8889
# Epoch 96/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0051 - accuracy: 0.9977 - val_loss: 0.6985 - val_accuracy: 0.8889
# Epoch 97/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0045 - accuracy: 0.9977 - val_loss: 0.7056 - val_accuracy: 0.8889
# Epoch 98/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.7043 - val_accuracy: 0.8889
# Epoch 99/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0086 - accuracy: 0.9954 - val_loss: 0.7205 - val_accuracy: 0.8796
# Epoch 100/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0034 - accuracy: 0.9977 - val_loss: 0.7248 - val_accuracy: 0.8796
# Test loss: 1.4719730615615845
# Test accuracy: 0.800000011920929
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81        71
#            1       0.78      0.81      0.79        64
#
#     accuracy                           0.80       135
#    macro avg       0.80      0.80      0.80       135
# weighted avg       0.80      0.80      0.80       135
#
# [[56 15]
#  [12 52]]

# %%
# SA
# Preprocess data
ts = ["Tempat panas", "tempat teduh kurang", "wisata tutup", "parkir kecil"]
t=[1,1,0,1]
tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(dsa['Ulasan'].astype(str))
X = tokenizer.texts_to_sequences(ts)
X = pad_sequences(X, maxlen=50, padding='post')

# Make predictions
predictions = model2.predict(X)
rounded_predictions = np.round(predictions).astype(int)

accuracy = accuracy_score(t, rounded_predictions)
report = classification_report(t, rounded_predictions)
cm = confusion_matrix(t, rounded_predictions)

print('Accuracy:', accuracy)
print(cm)
print(report)
# Out:
# Accuracy: 1.0
# [[1 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %%
model2.save('sa_f.h5')
