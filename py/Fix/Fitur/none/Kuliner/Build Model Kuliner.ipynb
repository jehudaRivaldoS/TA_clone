# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('d_sa.csv')

# %%
count_label = dsa['Kuliner'].value_counts()

# Membuat diagram batang
plt.bar(count_label.index, count_label.values)
plt.xticks([0, 1])
plt.xlabel('Label')
plt.ylabel('Jumlah Data')
plt.title('Distribusi Label pada Dataset')
plt.show()

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Kuliner']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 220ms/step - loss: 0.6471 - accuracy: 0.7703 - val_loss: 0.5408 - val_accuracy: 0.8426
# Epoch 2/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.5184 - accuracy: 0.8074 - val_loss: 0.4129 - val_accuracy: 0.8426
# Epoch 3/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.4567 - accuracy: 0.8074 - val_loss: 0.4129 - val_accuracy: 0.8426
# Epoch 4/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.4505 - accuracy: 0.8074 - val_loss: 0.4172 - val_accuracy: 0.8426
# Epoch 5/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4328 - accuracy: 0.8074 - val_loss: 0.3858 - val_accuracy: 0.8426
# Epoch 6/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.4227 - accuracy: 0.8074 - val_loss: 0.3765 - val_accuracy: 0.8426
# Epoch 7/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3929 - accuracy: 0.8074 - val_loss: 0.3620 - val_accuracy: 0.8426
# Epoch 8/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3730 - accuracy: 0.8074 - val_loss: 0.3365 - val_accuracy: 0.8426
# Epoch 9/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3315 - accuracy: 0.8167 - val_loss: 0.2758 - val_accuracy: 0.8981
# Epoch 10/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.2396 - accuracy: 0.9234 - val_loss: 0.2358 - val_accuracy: 0.9259
# Epoch 11/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.1400 - accuracy: 0.9652 - val_loss: 0.2384 - val_accuracy: 0.9074
# Epoch 12/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0810 - accuracy: 0.9814 - val_loss: 0.1945 - val_accuracy: 0.9444
# Epoch 13/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0613 - accuracy: 0.9884 - val_loss: 0.2355 - val_accuracy: 0.9259
# Epoch 14/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0475 - accuracy: 0.9907 - val_loss: 0.2571 - val_accuracy: 0.9259
# Epoch 15/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0508 - accuracy: 0.9861 - val_loss: 0.3047 - val_accuracy: 0.9074
# Epoch 16/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0828 - accuracy: 0.9768 - val_loss: 0.1730 - val_accuracy: 0.9444
# Epoch 17/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0333 - accuracy: 0.9954 - val_loss: 0.2263 - val_accuracy: 0.9352
# Epoch 18/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0199 - accuracy: 0.9977 - val_loss: 0.3095 - val_accuracy: 0.9259
# Epoch 19/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0156 - accuracy: 0.9977 - val_loss: 0.4495 - val_accuracy: 0.9074
# Epoch 20/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0118 - accuracy: 0.9977 - val_loss: 0.5035 - val_accuracy: 0.8981
# Epoch 21/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0235 - accuracy: 0.9954 - val_loss: 0.5346 - val_accuracy: 0.8889
# Epoch 22/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0155 - accuracy: 0.9977 - val_loss: 0.5328 - val_accuracy: 0.8889
# Epoch 23/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0145 - accuracy: 0.9977 - val_loss: 0.5110 - val_accuracy: 0.8981
# Epoch 24/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0193 - accuracy: 0.9954 - val_loss: 0.4539 - val_accuracy: 0.9167
# Epoch 25/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0126 - accuracy: 0.9977 - val_loss: 0.4521 - val_accuracy: 0.9167
# Epoch 26/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0123 - accuracy: 0.9977 - val_loss: 0.4551 - val_accuracy: 0.9167
# Epoch 27/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0138 - accuracy: 0.9977 - val_loss: 0.4619 - val_accuracy: 0.9167
# Epoch 28/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0130 - accuracy: 0.9977 - val_loss: 0.4672 - val_accuracy: 0.9167
# Epoch 29/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0144 - accuracy: 0.9977 - val_loss: 0.4717 - val_accuracy: 0.9167
# Epoch 30/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0322 - accuracy: 0.9954 - val_loss: 0.4993 - val_accuracy: 0.9074
# Epoch 31/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0139 - accuracy: 0.9977 - val_loss: 0.4995 - val_accuracy: 0.9074
# Epoch 32/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0465 - accuracy: 0.9930 - val_loss: 0.4115 - val_accuracy: 0.9352
# Epoch 33/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0923 - accuracy: 0.9791 - val_loss: 0.2423 - val_accuracy: 0.9259
# Epoch 34/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0523 - accuracy: 0.9907 - val_loss: 0.1815 - val_accuracy: 0.9444
# Epoch 35/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0209 - accuracy: 0.9977 - val_loss: 0.2175 - val_accuracy: 0.9537
# Epoch 36/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.2384 - val_accuracy: 0.9444
# Epoch 37/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2509 - val_accuracy: 0.9352
# Epoch 38/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2912 - val_accuracy: 0.9352
# Epoch 39/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2970 - val_accuracy: 0.9352
# Epoch 40/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3027 - val_accuracy: 0.9352
# Epoch 41/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.9444
# Epoch 42/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3097 - val_accuracy: 0.9444
# Epoch 43/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9444
# Epoch 44/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9444
# Epoch 45/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 0.9444
# Epoch 46/100
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3214 - val_accuracy: 0.9444
# Epoch 47/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3249 - val_accuracy: 0.9537
# Epoch 48/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3270 - val_accuracy: 0.9537
# Epoch 49/100
# 7/7 [==============================] - 0s 33ms/step - loss: 9.2849e-04 - accuracy: 1.0000 - val_loss: 0.3289 - val_accuracy: 0.9537
# Epoch 50/100
# 7/7 [==============================] - 0s 32ms/step - loss: 7.7431e-04 - accuracy: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.9537
# Epoch 51/100
# 7/7 [==============================] - 0s 35ms/step - loss: 8.4798e-04 - accuracy: 1.0000 - val_loss: 0.3336 - val_accuracy: 0.9537
# Epoch 52/100
# 7/7 [==============================] - 0s 33ms/step - loss: 7.0625e-04 - accuracy: 1.0000 - val_loss: 0.3359 - val_accuracy: 0.9537
# Epoch 53/100
# 7/7 [==============================] - 0s 34ms/step - loss: 7.6854e-04 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9537
# Epoch 54/100
# 7/7 [==============================] - 0s 33ms/step - loss: 6.3434e-04 - accuracy: 1.0000 - val_loss: 0.3405 - val_accuracy: 0.9537
# Epoch 55/100
# 7/7 [==============================] - 0s 32ms/step - loss: 6.5769e-04 - accuracy: 1.0000 - val_loss: 0.3426 - val_accuracy: 0.9537
# Epoch 56/100
# 7/7 [==============================] - 0s 32ms/step - loss: 5.7730e-04 - accuracy: 1.0000 - val_loss: 0.3446 - val_accuracy: 0.9537
# Epoch 57/100
# 7/7 [==============================] - 0s 31ms/step - loss: 5.3294e-04 - accuracy: 1.0000 - val_loss: 0.3465 - val_accuracy: 0.9537
# Epoch 58/100
# 7/7 [==============================] - 0s 34ms/step - loss: 5.1947e-04 - accuracy: 1.0000 - val_loss: 0.3483 - val_accuracy: 0.9537
# Epoch 59/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.9354e-04 - accuracy: 1.0000 - val_loss: 0.3501 - val_accuracy: 0.9537
# Epoch 60/100
# 7/7 [==============================] - 0s 33ms/step - loss: 4.9908e-04 - accuracy: 1.0000 - val_loss: 0.3518 - val_accuracy: 0.9537
# Epoch 61/100
# 7/7 [==============================] - 0s 32ms/step - loss: 5.4913e-04 - accuracy: 1.0000 - val_loss: 0.3536 - val_accuracy: 0.9537
# Epoch 62/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.7696e-04 - accuracy: 1.0000 - val_loss: 0.3554 - val_accuracy: 0.9537
# Epoch 63/100
# 7/7 [==============================] - 0s 35ms/step - loss: 4.2759e-04 - accuracy: 1.0000 - val_loss: 0.3571 - val_accuracy: 0.9537
# Epoch 64/100
# 7/7 [==============================] - 0s 34ms/step - loss: 4.1853e-04 - accuracy: 1.0000 - val_loss: 0.3588 - val_accuracy: 0.9537
# Epoch 65/100
# 7/7 [==============================] - 0s 33ms/step - loss: 4.5730e-04 - accuracy: 1.0000 - val_loss: 0.3604 - val_accuracy: 0.9537
# Epoch 66/100
# 7/7 [==============================] - 0s 33ms/step - loss: 4.5788e-04 - accuracy: 1.0000 - val_loss: 0.3622 - val_accuracy: 0.9537
# Epoch 67/100
# 7/7 [==============================] - 0s 31ms/step - loss: 3.7384e-04 - accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.9537
# Epoch 68/100
# 7/7 [==============================] - 0s 34ms/step - loss: 3.9024e-04 - accuracy: 1.0000 - val_loss: 0.3654 - val_accuracy: 0.9537
# Epoch 69/100
# 7/7 [==============================] - 0s 32ms/step - loss: 3.5318e-04 - accuracy: 1.0000 - val_loss: 0.3670 - val_accuracy: 0.9537
# Epoch 70/100
# 7/7 [==============================] - 0s 30ms/step - loss: 3.7933e-04 - accuracy: 1.0000 - val_loss: 0.3685 - val_accuracy: 0.9537
# Epoch 71/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.8324e-04 - accuracy: 1.0000 - val_loss: 0.3699 - val_accuracy: 0.9537
# Epoch 72/100
# 7/7 [==============================] - 0s 31ms/step - loss: 3.2064e-04 - accuracy: 1.0000 - val_loss: 0.3713 - val_accuracy: 0.9537
# Epoch 73/100
# 7/7 [==============================] - 0s 36ms/step - loss: 3.0444e-04 - accuracy: 1.0000 - val_loss: 0.3726 - val_accuracy: 0.9537
# Epoch 74/100
# 7/7 [==============================] - 0s 33ms/step - loss: 2.9922e-04 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 0.9537
# Epoch 75/100
# 7/7 [==============================] - 0s 35ms/step - loss: 3.2530e-04 - accuracy: 1.0000 - val_loss: 0.3752 - val_accuracy: 0.9537
# Epoch 76/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.8488e-04 - accuracy: 1.0000 - val_loss: 0.3766 - val_accuracy: 0.9537
# Epoch 77/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.7888e-04 - accuracy: 1.0000 - val_loss: 0.3781 - val_accuracy: 0.9537
# Epoch 78/100
# 7/7 [==============================] - 0s 36ms/step - loss: 2.6170e-04 - accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 0.9537
# Epoch 79/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.7471e-04 - accuracy: 1.0000 - val_loss: 0.3809 - val_accuracy: 0.9537
# Epoch 80/100
# 7/7 [==============================] - 0s 36ms/step - loss: 2.5173e-04 - accuracy: 1.0000 - val_loss: 0.3823 - val_accuracy: 0.9537
# Epoch 81/100
# 7/7 [==============================] - 0s 35ms/step - loss: 2.4831e-04 - accuracy: 1.0000 - val_loss: 0.3836 - val_accuracy: 0.9537
# Epoch 82/100
# 7/7 [==============================] - 0s 32ms/step - loss: 2.4906e-04 - accuracy: 1.0000 - val_loss: 0.3849 - val_accuracy: 0.9537
# Epoch 83/100
# 7/7 [==============================] - 0s 36ms/step - loss: 2.5951e-04 - accuracy: 1.0000 - val_loss: 0.3861 - val_accuracy: 0.9537
# Epoch 84/100
# 7/7 [==============================] - 0s 33ms/step - loss: 2.6070e-04 - accuracy: 1.0000 - val_loss: 0.3874 - val_accuracy: 0.9537
# Epoch 85/100
# 7/7 [==============================] - 0s 49ms/step - loss: 2.8175e-04 - accuracy: 1.0000 - val_loss: 0.3888 - val_accuracy: 0.9537
# Epoch 86/100
# 7/7 [==============================] - 0s 31ms/step - loss: 2.6822e-04 - accuracy: 1.0000 - val_loss: 0.3902 - val_accuracy: 0.9537
# Epoch 87/100
# 7/7 [==============================] - 0s 34ms/step - loss: 1.9358e-04 - accuracy: 1.0000 - val_loss: 0.3914 - val_accuracy: 0.9537
# Epoch 88/100
# 7/7 [==============================] - 0s 32ms/step - loss: 2.3902e-04 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.9537
# Epoch 89/100
# 7/7 [==============================] - 0s 33ms/step - loss: 2.3051e-04 - accuracy: 1.0000 - val_loss: 0.3937 - val_accuracy: 0.9537
# Epoch 90/100
# 7/7 [==============================] - 0s 36ms/step - loss: 2.0041e-04 - accuracy: 1.0000 - val_loss: 0.3948 - val_accuracy: 0.9537
# Epoch 91/100
# 7/7 [==============================] - 0s 33ms/step - loss: 2.0517e-04 - accuracy: 1.0000 - val_loss: 0.3959 - val_accuracy: 0.9537
# Epoch 92/100
# 7/7 [==============================] - 0s 37ms/step - loss: 2.2330e-04 - accuracy: 1.0000 - val_loss: 0.3970 - val_accuracy: 0.9537
# Epoch 93/100
# 7/7 [==============================] - 0s 34ms/step - loss: 2.1775e-04 - accuracy: 1.0000 - val_loss: 0.3980 - val_accuracy: 0.9537
# Epoch 94/100
# 7/7 [==============================] - 0s 36ms/step - loss: 2.0992e-04 - accuracy: 1.0000 - val_loss: 0.3990 - val_accuracy: 0.9537
# Epoch 95/100
# 7/7 [==============================] - 0s 41ms/step - loss: 2.3472e-04 - accuracy: 1.0000 - val_loss: 0.4000 - val_accuracy: 0.9537
# Epoch 96/100
# 7/7 [==============================] - 0s 33ms/step - loss: 1.8931e-04 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.9537
# Epoch 97/100
# 7/7 [==============================] - 0s 32ms/step - loss: 1.9503e-04 - accuracy: 1.0000 - val_loss: 0.4015 - val_accuracy: 0.9537
# Epoch 98/100
# 7/7 [==============================] - 0s 34ms/step - loss: 1.7593e-04 - accuracy: 1.0000 - val_loss: 0.4020 - val_accuracy: 0.9537
# Epoch 99/100
# 7/7 [==============================] - 0s 32ms/step - loss: 1.7517e-04 - accuracy: 1.0000 - val_loss: 0.4019 - val_accuracy: 0.9537
# Epoch 100/100
# 7/7 [==============================] - 0s 34ms/step - loss: 1.6669e-04 - accuracy: 1.0000 - val_loss: 0.4008 - val_accuracy: 0.9537
# Test loss: 0.34692153334617615
# Test accuracy: 0.9481481313705444
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       110
#            1       0.91      0.80      0.85        25
#
#     accuracy                           0.95       135
#    macro avg       0.93      0.89      0.91       135
# weighted avg       0.95      0.95      0.95       135
#
# [[108   2]
#  [  5  20]]

# %%
# SA
# Preprocess data
ts = ["Tempat bersih", "warung makan enak", "wisata tutup", "makan minum harga murah"]
t=[0,1,0,1]
tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(dsa['Ulasan'].astype(str))
X = tokenizer.texts_to_sequences(ts)
X = pad_sequences(X, maxlen=50, padding='post')

# Make predictions
predictions = model2.predict(X)
rounded_predictions = np.round(predictions).astype(int)

accuracy = accuracy_score(t, rounded_predictions)
report = classification_report(t, rounded_predictions)
cm = confusion_matrix(t, rounded_predictions)

print('Accuracy:', accuracy)
print(cm)
print(report)
# Out:
# Accuracy: 1.0
# [[2 0]
#  [0 2]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %%
model2.save('sa_k.h5')
