# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('d_sa.csv')

# %%
count_label = dsa['Wahana'].value_counts()

# Membuat diagram batang
plt.bar(count_label.index, count_label.values)
plt.xticks([0, 1])
plt.xlabel('Label')
plt.ylabel('Jumlah Data')
plt.title('Distribusi Label pada Dataset')
plt.show()

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Wahana']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 223ms/step - loss: 0.6623 - accuracy: 0.6937 - val_loss: 0.5992 - val_accuracy: 0.7222
# Epoch 2/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5948 - accuracy: 0.7123 - val_loss: 0.5445 - val_accuracy: 0.7222
# Epoch 3/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5499 - accuracy: 0.7123 - val_loss: 0.5423 - val_accuracy: 0.7222
# Epoch 4/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.5244 - accuracy: 0.7123 - val_loss: 0.5098 - val_accuracy: 0.7222
# Epoch 5/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.4967 - accuracy: 0.7123 - val_loss: 0.4911 - val_accuracy: 0.7222
# Epoch 6/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4753 - accuracy: 0.7169 - val_loss: 0.4719 - val_accuracy: 0.7963
# Epoch 7/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.4327 - accuracy: 0.8028 - val_loss: 0.4501 - val_accuracy: 0.8056
# Epoch 8/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.3713 - accuracy: 0.8956 - val_loss: 0.4237 - val_accuracy: 0.8333
# Epoch 9/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.2772 - accuracy: 0.9281 - val_loss: 0.4106 - val_accuracy: 0.8241
# Epoch 10/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1694 - accuracy: 0.9443 - val_loss: 0.4539 - val_accuracy: 0.8056
# Epoch 11/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.1068 - accuracy: 0.9606 - val_loss: 0.4108 - val_accuracy: 0.8611
# Epoch 12/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0975 - accuracy: 0.9722 - val_loss: 0.5769 - val_accuracy: 0.8056
# Epoch 13/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0649 - accuracy: 0.9814 - val_loss: 0.4446 - val_accuracy: 0.8796
# Epoch 14/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0449 - accuracy: 0.9930 - val_loss: 0.5305 - val_accuracy: 0.8148
# Epoch 15/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0418 - accuracy: 0.9930 - val_loss: 0.5148 - val_accuracy: 0.8148
# Epoch 16/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0262 - accuracy: 0.9954 - val_loss: 0.4805 - val_accuracy: 0.8519
# Epoch 17/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0281 - accuracy: 0.9954 - val_loss: 0.4676 - val_accuracy: 0.8519
# Epoch 18/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0308 - accuracy: 0.9954 - val_loss: 0.4504 - val_accuracy: 0.8704
# Epoch 19/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0275 - accuracy: 0.9954 - val_loss: 0.4397 - val_accuracy: 0.8889
# Epoch 20/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0295 - accuracy: 0.9930 - val_loss: 0.4547 - val_accuracy: 0.8704
# Epoch 21/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0182 - accuracy: 0.9977 - val_loss: 0.5308 - val_accuracy: 0.8519
# Epoch 22/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0219 - accuracy: 0.9930 - val_loss: 0.5173 - val_accuracy: 0.8426
# Epoch 23/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0194 - accuracy: 0.9977 - val_loss: 0.5093 - val_accuracy: 0.8704
# Epoch 24/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0199 - accuracy: 0.9977 - val_loss: 0.5087 - val_accuracy: 0.8704
# Epoch 25/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0175 - accuracy: 0.9977 - val_loss: 0.5066 - val_accuracy: 0.8796
# Epoch 26/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0197 - accuracy: 0.9977 - val_loss: 0.5204 - val_accuracy: 0.8796
# Epoch 27/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0192 - accuracy: 0.9954 - val_loss: 0.5110 - val_accuracy: 0.8796
# Epoch 28/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0189 - accuracy: 0.9977 - val_loss: 0.4971 - val_accuracy: 0.8796
# Epoch 29/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0176 - accuracy: 0.9977 - val_loss: 0.4899 - val_accuracy: 0.8796
# Epoch 30/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0166 - accuracy: 0.9977 - val_loss: 0.4986 - val_accuracy: 0.8796
# Epoch 31/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0183 - accuracy: 0.9977 - val_loss: 0.5189 - val_accuracy: 0.8889
# Epoch 32/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0138 - accuracy: 0.9977 - val_loss: 0.5414 - val_accuracy: 0.8796
# Epoch 33/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0175 - accuracy: 0.9977 - val_loss: 0.5581 - val_accuracy: 0.8796
# Epoch 34/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0183 - accuracy: 0.9977 - val_loss: 0.5698 - val_accuracy: 0.8704
# Epoch 35/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0197 - accuracy: 0.9977 - val_loss: 0.5939 - val_accuracy: 0.8519
# Epoch 36/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0176 - accuracy: 0.9977 - val_loss: 0.5925 - val_accuracy: 0.8704
# Epoch 37/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0167 - accuracy: 0.9977 - val_loss: 0.6034 - val_accuracy: 0.8426
# Epoch 38/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0156 - accuracy: 0.9977 - val_loss: 0.6077 - val_accuracy: 0.8426
# Epoch 39/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0104 - accuracy: 0.9977 - val_loss: 0.6098 - val_accuracy: 0.8426
# Epoch 40/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0168 - accuracy: 0.9977 - val_loss: 0.6287 - val_accuracy: 0.8426
# Epoch 41/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0206 - accuracy: 0.9977 - val_loss: 0.6404 - val_accuracy: 0.8426
# Epoch 42/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0184 - accuracy: 0.9977 - val_loss: 0.6616 - val_accuracy: 0.8333
# Epoch 43/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0153 - accuracy: 0.9977 - val_loss: 0.6503 - val_accuracy: 0.8333
# Epoch 44/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0165 - accuracy: 0.9977 - val_loss: 0.6226 - val_accuracy: 0.8611
# Epoch 45/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0136 - accuracy: 0.9977 - val_loss: 0.6394 - val_accuracy: 0.8426
# Epoch 46/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0176 - accuracy: 0.9977 - val_loss: 0.6452 - val_accuracy: 0.8426
# Epoch 47/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0155 - accuracy: 0.9977 - val_loss: 0.6825 - val_accuracy: 0.8241
# Epoch 48/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0150 - accuracy: 0.9977 - val_loss: 0.7152 - val_accuracy: 0.8333
# Epoch 49/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0162 - accuracy: 0.9977 - val_loss: 0.5454 - val_accuracy: 0.8796
# Epoch 50/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0115 - accuracy: 0.9977 - val_loss: 0.4492 - val_accuracy: 0.8981
# Epoch 51/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0147 - accuracy: 0.9977 - val_loss: 0.4444 - val_accuracy: 0.8981
# Epoch 52/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0164 - accuracy: 0.9977 - val_loss: 0.4694 - val_accuracy: 0.8981
# Epoch 53/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0162 - accuracy: 0.9977 - val_loss: 0.4908 - val_accuracy: 0.8889
# Epoch 54/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0159 - accuracy: 0.9977 - val_loss: 0.5327 - val_accuracy: 0.8796
# Epoch 55/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0165 - accuracy: 0.9977 - val_loss: 0.5821 - val_accuracy: 0.8519
# Epoch 56/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0169 - accuracy: 0.9977 - val_loss: 0.6113 - val_accuracy: 0.8426
# Epoch 57/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0107 - accuracy: 0.9977 - val_loss: 0.6526 - val_accuracy: 0.8333
# Epoch 58/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0172 - accuracy: 0.9930 - val_loss: 0.6630 - val_accuracy: 0.8426
# Epoch 59/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 0.5238 - val_accuracy: 0.8796
# Epoch 60/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0414 - accuracy: 0.9884 - val_loss: 0.4578 - val_accuracy: 0.8889
# Epoch 61/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0192 - accuracy: 0.9977 - val_loss: 0.6085 - val_accuracy: 0.8611
# Epoch 62/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0349 - accuracy: 0.9930 - val_loss: 0.6005 - val_accuracy: 0.8611
# Epoch 63/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0214 - accuracy: 0.9954 - val_loss: 0.5520 - val_accuracy: 0.8519
# Epoch 64/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0142 - accuracy: 0.9977 - val_loss: 0.5471 - val_accuracy: 0.8519
# Epoch 65/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0153 - accuracy: 0.9977 - val_loss: 0.5427 - val_accuracy: 0.8704
# Epoch 66/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 0.5514 - val_accuracy: 0.8611
# Epoch 67/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0157 - accuracy: 0.9977 - val_loss: 0.5564 - val_accuracy: 0.8519
# Epoch 68/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0148 - accuracy: 0.9977 - val_loss: 0.5590 - val_accuracy: 0.8519
# Epoch 69/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0151 - accuracy: 0.9977 - val_loss: 0.5649 - val_accuracy: 0.8519
# Epoch 70/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0120 - accuracy: 0.9977 - val_loss: 0.5750 - val_accuracy: 0.8519
# Epoch 71/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0150 - accuracy: 0.9977 - val_loss: 0.5916 - val_accuracy: 0.8426
# Epoch 72/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.6620 - val_accuracy: 0.8241
# Epoch 73/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0229 - accuracy: 0.9907 - val_loss: 0.7369 - val_accuracy: 0.7963
# Epoch 74/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0111 - accuracy: 0.9930 - val_loss: 0.5586 - val_accuracy: 0.8796
# Epoch 75/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.5459 - val_accuracy: 0.9074
# Epoch 76/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.5641 - val_accuracy: 0.8981
# Epoch 77/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0076 - accuracy: 0.9954 - val_loss: 0.6076 - val_accuracy: 0.8611
# Epoch 78/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.5990 - val_accuracy: 0.8796
# Epoch 79/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.5654 - val_accuracy: 0.9074
# Epoch 80/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0112 - accuracy: 0.9977 - val_loss: 0.5694 - val_accuracy: 0.9074
# Epoch 81/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.5648 - val_accuracy: 0.9074
# Epoch 82/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.5598 - val_accuracy: 0.8981
# Epoch 83/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0043 - accuracy: 0.9977 - val_loss: 0.5639 - val_accuracy: 0.8981
# Epoch 84/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0047 - accuracy: 0.9977 - val_loss: 0.5747 - val_accuracy: 0.8889
# Epoch 85/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0047 - accuracy: 0.9977 - val_loss: 0.5907 - val_accuracy: 0.8796
# Epoch 86/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.5758 - val_accuracy: 0.9074
# Epoch 87/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5705 - val_accuracy: 0.9074
# Epoch 88/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0042 - accuracy: 0.9977 - val_loss: 0.5765 - val_accuracy: 0.9074
# Epoch 89/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0060 - accuracy: 0.9954 - val_loss: 0.6307 - val_accuracy: 0.8611
# Epoch 90/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0041 - accuracy: 0.9977 - val_loss: 0.5868 - val_accuracy: 0.9074
# Epoch 91/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0033 - accuracy: 0.9977 - val_loss: 0.6032 - val_accuracy: 0.8981
# Epoch 92/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6136 - val_accuracy: 0.8704
# Epoch 93/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5891 - val_accuracy: 0.9074
# Epoch 94/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5842 - val_accuracy: 0.9074
# Epoch 95/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0044 - accuracy: 0.9977 - val_loss: 0.5901 - val_accuracy: 0.9074
# Epoch 96/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0035 - accuracy: 0.9977 - val_loss: 0.6020 - val_accuracy: 0.8889
# Epoch 97/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0082 - accuracy: 0.9954 - val_loss: 0.6099 - val_accuracy: 0.8611
# Epoch 98/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.6182 - val_accuracy: 0.8426
# Epoch 99/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.5780 - val_accuracy: 0.8889
# Epoch 100/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5566 - val_accuracy: 0.9074
# Test loss: 0.42888858914375305
# Test accuracy: 0.9333333373069763
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        97
#            1       0.91      0.84      0.88        38
#
#     accuracy                           0.93       135
#    macro avg       0.93      0.91      0.92       135
# weighted avg       0.93      0.93      0.93       135
#
# [[94  3]
#  [ 6 32]]

# %%
ts = ["Tempat bersih", "kereta keliling puas", "sepeda air mati", "kolam ikan jelek"]
t=[0,1,1,1]
tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(dsa['Ulasan'].astype(str))
X = tokenizer.texts_to_sequences(ts)
X = pad_sequences(X, maxlen=50, padding='post')

# Make predictions
predictions = model2.predict(X)
rounded_predictions = np.round(predictions).astype(int)

accuracy = accuracy_score(t, rounded_predictions)
report = classification_report(t, rounded_predictions)
cm = confusion_matrix(t, rounded_predictions)

print('Accuracy:', accuracy)
print(cm)
print(report)
# Out:
# Accuracy: 1.0
# [[1 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4

# %%
model2.save('sa_w.h5')
