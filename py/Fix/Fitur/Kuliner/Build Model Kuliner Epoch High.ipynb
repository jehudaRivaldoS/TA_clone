# %%
#Import Library
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional 
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
#load dataset after preprocessing
dsa = pd.read_csv('data_ap_s_a_k.csv')

# %%
count_label = dsa['Kuliner'].value_counts()

# Membuat diagram batang
plt.bar(count_label.index, count_label.values)
plt.xticks([0, 1])
plt.xlabel('Label')
plt.ylabel('Jumlah Data')
plt.title('Distribusi Label pada Dataset')
plt.show()

# %%
#Model Sentiment with Sastrawi stopword and Nazief Adriani Stemmer
texts = dsa['Ulasan']
labels = dsa['Kuliner']

#Tokenizer and Pad Sequence
dsa_token = Tokenizer(num_words=10000, oov_token='<OOV>')
dsa_token.fit_on_texts(texts)
X = dsa_token.texts_to_sequences(texts)
X = pad_sequences(X, maxlen=50, padding='post')
y = labels
le = LabelEncoder()
y = le.fit_transform(y)
inputembedd = len(dsa_token.word_index) + 1

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify = y,  random_state=42)

#Define LSTM model
model2 = Sequential()
model2.add(Embedding(input_dim = inputembedd, input_length = 50, output_dim = 50))
model2.add(Bidirectional(LSTM(units = 64, dropout = 0.2, return_sequences = True)))
model2.add(Dropout(0.6))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(32, activation='relu'))
model2.add(Bidirectional(LSTM(units = 32)))
model2.add(Dropout(0.4))
model2.add(Dense(1, activation='sigmoid'))

# Compile model
model2.compile(loss='binary_crossentropy', optimizer="adam", metrics=['accuracy'])

# Train model
history = model2.fit(X_train, y_train, epochs=100, validation_split=0.2, batch_size=64)

# Evaluate model on test set
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

y_pred = model2.predict(X_test)
y_pred = np.round(y_pred).astype(int)
report = classification_report(y_test, y_pred)
print(report)

cm = confusion_matrix(y_test, y_pred)
print(cm)

# Plot grafik
train_loss = history.history['loss']
ac = history.history['val_loss']
plt.plot(train_loss, label='Training Loss')
plt.plot(ac, label='Val Loss')
plt.title('Training and Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
train_loss = history.history['accuracy']
ac = history.history['val_accuracy']
plt.plot(train_loss, label='Training Accuracy')
plt.plot(ac, label='Val Accuracy')
plt.title('Training and Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Acc')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 7/7 [==============================] - 7s 303ms/step - loss: 0.6592 - accuracy: 0.7541 - val_loss: 0.5623 - val_accuracy: 0.8426
# Epoch 2/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.5084 - accuracy: 0.7981 - val_loss: 0.4303 - val_accuracy: 0.8426
# Epoch 3/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.4658 - accuracy: 0.7981 - val_loss: 0.4231 - val_accuracy: 0.8426
# Epoch 4/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.4434 - accuracy: 0.7981 - val_loss: 0.4032 - val_accuracy: 0.8426
# Epoch 5/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4195 - accuracy: 0.7981 - val_loss: 0.3985 - val_accuracy: 0.8426
# Epoch 6/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.4165 - accuracy: 0.7981 - val_loss: 0.3909 - val_accuracy: 0.8426
# Epoch 7/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.3905 - accuracy: 0.7981 - val_loss: 0.3812 - val_accuracy: 0.8426
# Epoch 8/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.3345 - accuracy: 0.8608 - val_loss: 0.3369 - val_accuracy: 0.8796
# Epoch 9/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2378 - accuracy: 0.9188 - val_loss: 0.3072 - val_accuracy: 0.8981
# Epoch 10/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1939 - accuracy: 0.9350 - val_loss: 0.2553 - val_accuracy: 0.9167
# Epoch 11/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.1541 - accuracy: 0.9420 - val_loss: 0.2737 - val_accuracy: 0.8981
# Epoch 12/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.1491 - accuracy: 0.9559 - val_loss: 0.2842 - val_accuracy: 0.9074
# Epoch 13/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.1350 - accuracy: 0.9698 - val_loss: 0.2674 - val_accuracy: 0.9074
# Epoch 14/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1077 - accuracy: 0.9791 - val_loss: 0.2318 - val_accuracy: 0.9167
# Epoch 15/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0904 - accuracy: 0.9791 - val_loss: 0.2728 - val_accuracy: 0.9167
# Epoch 16/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0847 - accuracy: 0.9814 - val_loss: 0.2003 - val_accuracy: 0.9259
# Epoch 17/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0746 - accuracy: 0.9884 - val_loss: 0.2261 - val_accuracy: 0.9259
# Epoch 18/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0705 - accuracy: 0.9838 - val_loss: 0.2679 - val_accuracy: 0.9259
# Epoch 19/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0673 - accuracy: 0.9838 - val_loss: 0.2965 - val_accuracy: 0.9259
# Epoch 20/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0696 - accuracy: 0.9861 - val_loss: 0.3469 - val_accuracy: 0.9167
# Epoch 21/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0680 - accuracy: 0.9861 - val_loss: 0.2655 - val_accuracy: 0.9167
# Epoch 22/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0865 - accuracy: 0.9745 - val_loss: 0.2890 - val_accuracy: 0.9074
# Epoch 23/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0658 - accuracy: 0.9838 - val_loss: 0.3251 - val_accuracy: 0.9259
# Epoch 24/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0554 - accuracy: 0.9861 - val_loss: 0.4747 - val_accuracy: 0.8796
# Epoch 25/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0543 - accuracy: 0.9861 - val_loss: 0.4685 - val_accuracy: 0.8889
# Epoch 26/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0979 - accuracy: 0.9698 - val_loss: 0.3343 - val_accuracy: 0.8889
# Epoch 27/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0586 - accuracy: 0.9838 - val_loss: 0.1946 - val_accuracy: 0.9352
# Epoch 28/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0561 - accuracy: 0.9838 - val_loss: 0.1908 - val_accuracy: 0.9352
# Epoch 29/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0453 - accuracy: 0.9861 - val_loss: 0.3052 - val_accuracy: 0.9259
# Epoch 30/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0349 - accuracy: 0.9907 - val_loss: 0.5166 - val_accuracy: 0.8889
# Epoch 31/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0314 - accuracy: 0.9884 - val_loss: 0.3671 - val_accuracy: 0.9167
# Epoch 32/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0417 - accuracy: 0.9861 - val_loss: 0.2942 - val_accuracy: 0.9259
# Epoch 33/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0408 - accuracy: 0.9884 - val_loss: 0.2580 - val_accuracy: 0.9352
# Epoch 34/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0366 - accuracy: 0.9861 - val_loss: 0.2532 - val_accuracy: 0.9259
# Epoch 35/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0312 - accuracy: 0.9884 - val_loss: 0.2979 - val_accuracy: 0.9167
# Epoch 36/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0321 - accuracy: 0.9884 - val_loss: 0.3557 - val_accuracy: 0.9167
# Epoch 37/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0291 - accuracy: 0.9907 - val_loss: 0.3596 - val_accuracy: 0.9167
# Epoch 38/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0292 - accuracy: 0.9884 - val_loss: 0.3625 - val_accuracy: 0.9167
# Epoch 39/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0265 - accuracy: 0.9930 - val_loss: 0.3581 - val_accuracy: 0.9167
# Epoch 40/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0268 - accuracy: 0.9930 - val_loss: 0.3584 - val_accuracy: 0.9167
# Epoch 41/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0284 - accuracy: 0.9884 - val_loss: 0.3349 - val_accuracy: 0.9167
# Epoch 42/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0270 - accuracy: 0.9907 - val_loss: 0.3393 - val_accuracy: 0.9074
# Epoch 43/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0225 - accuracy: 0.9907 - val_loss: 0.3244 - val_accuracy: 0.9259
# Epoch 44/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0219 - accuracy: 0.9907 - val_loss: 0.3371 - val_accuracy: 0.9167
# Epoch 45/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0243 - accuracy: 0.9930 - val_loss: 0.4242 - val_accuracy: 0.9074
# Epoch 46/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0380 - accuracy: 0.9884 - val_loss: 0.5831 - val_accuracy: 0.8889
# Epoch 47/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0453 - accuracy: 0.9884 - val_loss: 0.5428 - val_accuracy: 0.8704
# Epoch 48/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0162 - accuracy: 0.9954 - val_loss: 0.5479 - val_accuracy: 0.8796
# Epoch 49/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0220 - accuracy: 0.9884 - val_loss: 0.5816 - val_accuracy: 0.8704
# Epoch 50/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0434 - accuracy: 0.9884 - val_loss: 0.5931 - val_accuracy: 0.8704
# Epoch 51/100
# 7/7 [==============================] - 0s 63ms/step - loss: 0.0698 - accuracy: 0.9814 - val_loss: 0.5176 - val_accuracy: 0.8704
# Epoch 52/100
# 7/7 [==============================] - 0s 65ms/step - loss: 0.0625 - accuracy: 0.9861 - val_loss: 0.4046 - val_accuracy: 0.8889
# Epoch 53/100
# 7/7 [==============================] - 0s 61ms/step - loss: 0.0469 - accuracy: 0.9861 - val_loss: 0.3507 - val_accuracy: 0.9074
# Epoch 54/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0353 - accuracy: 0.9884 - val_loss: 0.3106 - val_accuracy: 0.9167
# Epoch 55/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0189 - accuracy: 0.9907 - val_loss: 0.2100 - val_accuracy: 0.9074
# Epoch 56/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0511 - accuracy: 0.9814 - val_loss: 0.2024 - val_accuracy: 0.9167
# Epoch 57/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0455 - accuracy: 0.9838 - val_loss: 0.1911 - val_accuracy: 0.9444
# Epoch 58/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0363 - accuracy: 0.9884 - val_loss: 0.2083 - val_accuracy: 0.9167
# Epoch 59/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0285 - accuracy: 0.9884 - val_loss: 0.2214 - val_accuracy: 0.9167
# Epoch 60/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0259 - accuracy: 0.9907 - val_loss: 0.2337 - val_accuracy: 0.9074
# Epoch 61/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0252 - accuracy: 0.9884 - val_loss: 0.2377 - val_accuracy: 0.9074
# Epoch 62/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0249 - accuracy: 0.9884 - val_loss: 0.2463 - val_accuracy: 0.9074
# Epoch 63/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0227 - accuracy: 0.9907 - val_loss: 0.2598 - val_accuracy: 0.9074
# Epoch 64/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0228 - accuracy: 0.9907 - val_loss: 0.2719 - val_accuracy: 0.9074
# Epoch 65/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0213 - accuracy: 0.9930 - val_loss: 0.3096 - val_accuracy: 0.8981
# Epoch 66/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0217 - accuracy: 0.9907 - val_loss: 0.3158 - val_accuracy: 0.8981
# Epoch 67/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0191 - accuracy: 0.9884 - val_loss: 0.3560 - val_accuracy: 0.8981
# Epoch 68/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0258 - accuracy: 0.9907 - val_loss: 0.3156 - val_accuracy: 0.8981
# Epoch 69/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0240 - accuracy: 0.9884 - val_loss: 0.2899 - val_accuracy: 0.8981
# Epoch 70/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0204 - accuracy: 0.9907 - val_loss: 0.3013 - val_accuracy: 0.8981
# Epoch 71/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0166 - accuracy: 0.9884 - val_loss: 0.3263 - val_accuracy: 0.8981
# Epoch 72/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0242 - accuracy: 0.9884 - val_loss: 0.3074 - val_accuracy: 0.9074
# Epoch 73/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0166 - accuracy: 0.9884 - val_loss: 0.3061 - val_accuracy: 0.9074
# Epoch 74/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0180 - accuracy: 0.9884 - val_loss: 0.3108 - val_accuracy: 0.9074
# Epoch 75/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0144 - accuracy: 0.9930 - val_loss: 0.3326 - val_accuracy: 0.8981
# Epoch 76/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0175 - accuracy: 0.9907 - val_loss: 0.3218 - val_accuracy: 0.8981
# Epoch 77/100
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0180 - accuracy: 0.9907 - val_loss: 0.3042 - val_accuracy: 0.8889
# Epoch 78/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0191 - accuracy: 0.9884 - val_loss: 0.3077 - val_accuracy: 0.8889
# Epoch 79/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0187 - accuracy: 0.9861 - val_loss: 0.3049 - val_accuracy: 0.8981
# Epoch 80/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0133 - accuracy: 0.9930 - val_loss: 0.3126 - val_accuracy: 0.8981
# Epoch 81/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0165 - accuracy: 0.9930 - val_loss: 0.3208 - val_accuracy: 0.8889
# Epoch 82/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0139 - accuracy: 0.9930 - val_loss: 0.3430 - val_accuracy: 0.8981
# Epoch 83/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0176 - accuracy: 0.9907 - val_loss: 0.3358 - val_accuracy: 0.8889
# Epoch 84/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0169 - accuracy: 0.9907 - val_loss: 0.3349 - val_accuracy: 0.8889
# Epoch 85/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0174 - accuracy: 0.9884 - val_loss: 0.3446 - val_accuracy: 0.8981
# Epoch 86/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0129 - accuracy: 0.9930 - val_loss: 0.3622 - val_accuracy: 0.8981
# Epoch 87/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0176 - accuracy: 0.9884 - val_loss: 0.3502 - val_accuracy: 0.8889
# Epoch 88/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0137 - accuracy: 0.9930 - val_loss: 0.3466 - val_accuracy: 0.8889
# Epoch 89/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0196 - accuracy: 0.9861 - val_loss: 0.3434 - val_accuracy: 0.8796
# Epoch 90/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0144 - accuracy: 0.9930 - val_loss: 0.3430 - val_accuracy: 0.8796
# Epoch 91/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0153 - accuracy: 0.9884 - val_loss: 0.3717 - val_accuracy: 0.8889
# Epoch 92/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0163 - accuracy: 0.9884 - val_loss: 0.3658 - val_accuracy: 0.8889
# Epoch 93/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0163 - accuracy: 0.9884 - val_loss: 0.3503 - val_accuracy: 0.8889
# Epoch 94/100
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0167 - accuracy: 0.9884 - val_loss: 0.3325 - val_accuracy: 0.8981
# Epoch 95/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0175 - accuracy: 0.9930 - val_loss: 0.3343 - val_accuracy: 0.8981
# Epoch 96/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 0.3553 - val_accuracy: 0.8981
# Epoch 97/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0150 - accuracy: 0.9907 - val_loss: 0.3560 - val_accuracy: 0.8889
# Epoch 98/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 0.3515 - val_accuracy: 0.8796
# Epoch 99/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0185 - accuracy: 0.9884 - val_loss: 0.3645 - val_accuracy: 0.8889
# Epoch 100/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0157 - accuracy: 0.9907 - val_loss: 0.3575 - val_accuracy: 0.8889
# Test loss: 0.48970529437065125
# Test accuracy: 0.9185185432434082
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       109
#            1       0.86      0.69      0.77        26
#
#     accuracy                           0.92       135
#    macro avg       0.89      0.83      0.86       135
# weighted avg       0.92      0.92      0.92       135
#
# [[106   3]
#  [  8  18]]

# %%
# NA
# Preprocess data
data = ["kereta bagus", "layan tidak sopan", "pegawai tidak ramah", "makan enak", "makan enak bagus", "minum dingin"]
label = [0,0,0,1,1,1]
tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
tokenizer.fit_on_texts(dsa['Ulasan'].astype(str))
X = tokenizer.texts_to_sequences(data)
X = pad_sequences(X, maxlen=50, padding='post')

# Make predictions
predictions = model2.predict(X)
rounded_predictions = np.round(predictions).astype(int)

accuracy = accuracy_score(label, rounded_predictions)
report = classification_report(label, rounded_predictions)
cm = confusion_matrix(label, rounded_predictions)

print('Accuracy:', accuracy)
print(cm)
print(report)
# Out:
# Accuracy: 1.0
# [[3 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %%
model2.save('s_a_kn.h5')
